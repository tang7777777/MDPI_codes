# %%
from datasets import load_dataset
from datasets import Dataset
dataset = load_dataset('trec')
#display(dataset)
dataset = dataset.remove_columns("label-fine")
#display(dataset)
dataset = dataset.rename_column("label-coarse", "label")
display(dataset)


train_validation_ds = dataset['train'].shuffle(seed=42).select([i for i in list(range(5000))])
original_train_ds = Dataset.from_dict(train_validation_ds[0:4500])
validation_ds = Dataset.from_dict(train_validation_ds[4500:5000])
test_ds = dataset['test'].shuffle(seed=42).select([i for i in list(range(500))])

display(original_train_ds)
display(validation_ds)
display(test_ds)
# Out:
# Using custom data configuration default
# Reusing dataset trec (C:\Users\DELL\.cache\huggingface\datasets\trec\default\1.1.0\751da1ab101b8d297a3d6e9c79ee9b0173ff94c4497b75677b59b61d5467a9b9)
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 667.88it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'text'],
#         num_rows: 5452
#     })
#     test: Dataset({
#         features: ['label', 'text'],
#         num_rows: 500
#     })
# })
# Loading cached shuffled indices for dataset at C:\Users\DELL\.cache\huggingface\datasets\trec\default\1.1.0\751da1ab101b8d297a3d6e9c79ee9b0173ff94c4497b75677b59b61d5467a9b9\cache-bc761497303cb1ab.arrow
# Loading cached shuffled indices for dataset at C:\Users\DELL\.cache\huggingface\datasets\trec\default\1.1.0\751da1ab101b8d297a3d6e9c79ee9b0173ff94c4497b75677b59b61d5467a9b9\cache-d432b7eeb4042bcd.arrow
# Dataset({
#     features: ['label', 'text'],
#     num_rows: 4500
# })
# Dataset({
#     features: ['label', 'text'],
#     num_rows: 500
# })
# Dataset({
#     features: ['label', 'text'],
#     num_rows: 500
# })

# %%
import pandas as pd 

original_train_df = pd.DataFrame(original_train_ds) 
display(original_train_df)
# Out:
#       label                                               text
# 0         0  How can I transport files from one computer to...
# 1         3  Who are the two sons of Ozzie and Harriet Nels...
# 2         2                           What does pH stand for ?
# 3         4    How many people does Honda employ in the U.S. ?
# 4         1  What newspaper returned a Pulitzer Prize for t...
# ...     ...                                                ...
# 4495      1  What does Final Four refer to in the sports wo...
# 4496      3              What is Nicholas Cage 's occupation ?
# 4497      1  In order from the top , the four stripes on a ...
# 4498      3                What kind of business is 7-Eleven ?
# 4499      1  What soft drink held a national flavor poll in...
#
# [4500 rows x 2 columns]

# %%
import pandas as pd 

augmented_train_df = pd.read_csv(r'C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\augumented_dataset\CheckList\run3\dataset.csv')
display(augmented_train_df)
# Out:
#       Unnamed: 0                                      original_text  \
# 0              0  How can I transport files from one computer to...
# 1              1  Who are the two sons of Ozzie and Harriet Nels...
# 2              2  Who was the mother of the man who would not be...
# 3              3  What chocolate company gives you a one-pound k...
# 4              4  Whom does Uncle Duke 's girl friend , Honey , ...
# ...          ...                                                ...
# 1360        1360             Name one of King Henry VIII 's wives .
# 1361        1361  What did Mighty Mouse always sing as he went i...
# 1362        1362              What is Nicholas Cage 's occupation ?
# 1363        1363                What kind of business is 7-Eleven ?
# 1364        1364  What soft drink held a national flavor poll in...
#
#                                          perturbed_text
# 0     How can I transport files from two computer to...
# 1     Who are the two sons of Ozzie and Harriet Grub...
# 2     Who was the mother of the man who wouldn't be ...
# 3         What chocolate company gives you a two kiss ?
# 4     Whom does Uncle Stith 's girl friend , Honey ,...
# ...                                                 ...
# 1360          Name one of King Henry Cornejo 's wives .
# 1361  What did Mighty Marchant always sing as he wen...
# 1362                What is Deshun Cage 's occupation ?
# 1363              What kind of business is twenty-two ?
# 1364  What soft drink held a national flavor poll in...
#
# [1365 rows x 3 columns]

# %%
import itertools
perturbed_label_list = []
for index, data in augmented_train_df.iterrows():
    original_label = (original_train_df[original_train_df['text'] == data['original_text']])['label']
    if (list(original_label)):
        print(list(set(original_label)))
        perturbed_label_list.append(list(set(original_label)))

perturbed_label_list = list(itertools.chain.from_iterable(perturbed_label_list))
#display(perturbed_label_list)
display(len(perturbed_label_list))
# Out:
# [0]
# [3]
# [3]
# [3]
# [3]
# [1]
# [4]
# [5]
# [1]
# [3]
# [3]
# [3]
# [5]
# [1]
# [4]
# [1]
# [4]
# [4]
# [3]
# [0]
# [0]
# [4]
# [3]
# [0]
# [1]
# [0]
# [3]
# [0]
# [4]
# [3]
# [3]
# [3]
# [4]
# [3]
# [0]
# [5]
# [4]
# [4]
# [3]
# [3]
# [1]
# [3]
# [0]
# [5]
# [3]
# [4]
# [4]
# [3]
# [3]
# [3]
# [3]
# [3]
# [3]
# [5]
# [1]
# [3]
# [4]
# [1]
# [5]
# [3]
# [0]
# [4]
# [4]
# [3]
# [4]
# [4]
# [1]
# [1]
# [3]
# [1]
# [0]
# [3]
# [3]
# [3]
# [3]
# [4]
# [3]
# [3]
# [0]
# [3]
# [4]
# [3]
# [4]
# [1]
# [1]
# [5]
# [0]
# [0]
# [5]
# [4]
# [3]
# [4]
# [4]
# [4]
# [5]
# [1]
# [3]
# [3]
# [3]
# [5]
# [5]
# [4]
# [1]
# [0]
# [0]
# [3]
# [5]
# [1]
# [1]
# [1]
# [1]
# [4]
# [3]
# [4]
# [3]
# [3]
# [3]
# [5]
# [0]
# [4]
# [1]
# [4]
# [3]
# [3]
# [5]
# [1]
# [3]
# [0]
# [1]
# [1]
# [1]
# [4]
# [3]
# [5]
# [3]
# [3]
# [1]
# [1]
# [4]
# [5]
# [3]
# [5]
# [4]
# [3]
# [4]
# [3]
# [1]
# [4]
# [3]
# [1]
# [1]
# [1]
# [3]
# [1]
# [0]
# [1]
# [1]
# [1]
# [3]
# [0]
# [3]
# [3]
# [4]
# [3]
# [5]
# [3]
# [1]
# [3]
# [3]
# [1]
# [0]
# [1]
# [5]
# [0]
# [5]
# [1]
# [3]
# [5]
# [3]
# [1]
# [0]
# [0]
# [3]
# [1]
# [0]
# [4]
# [1]
# [3]
# [1]
# [0]
# [0]
# [3]
# [3]
# [3]
# [0]
# [4]
# [4]
# [4]
# [3]
# [5]
# [1]
# [4]
# [1]
# [5]
# [1]
# [3]
# [5]
# [3]
# [3]
# [1]
# [1]
# [4]
# [3]
# [5]
# [3]
# [0]
# [3]
# [3]
# [3]
# [5]
# [3]
# [3]
# [3]
# [3]
# [3]
# [1]
# [1]
# [3]
# [3]
# [4]
# [3]
# [1]
# [0]
# [5]
# [4]
# [3]
# [1]
# [3]
# [5]
# [5]
# [3]
# [4]
# 1363        1363                What kind of business is 7-Eleven ?
# 1364        1364  What soft drink held a national flavor poll in...
#
#                                          perturbed_text  perturbed_label
# 0     How can I transport files from two computer to...                0
# 1     Who are the two sons of Ozzie and Harriet Grub...                3
# 2     Who was the mother of the man who wouldn't be ...                3
# 3         What chocolate company gives you a two kiss ?                3
# 4     Whom does Uncle Stith 's girl friend , Honey ,...                3
# ...                                                 ...              ...
# 1360          Name one of King Henry Cornejo 's wives .                3
# 1361  What did Mighty Marchant always sing as he wen...                0
# 1362                What is Deshun Cage 's occupation ?                3
# 1363              What kind of business is twenty-two ?                3
# 1364  What soft drink held a national flavor poll in...                1
#
# [1365 rows x 4 columns]

# %%
target = augmented_train_df.index[augmented_train_df['perturbed_text'] == 'Error occured in text generation .']
augmented_train_df =  augmented_train_df.drop(target)

# %%
drop_col = ['Unnamed: 0', 'original_text']
augmented_train_df = augmented_train_df.drop(drop_col, axis=1)
display(augmented_train_df)
# Out:
#                                          perturbed_text  perturbed_label
# 0     How can I transport files from two computer to...                0
# 1     Who are the two sons of Ozzie and Harriet Grub...                3
# 2     Who was the mother of the man who wouldn't be ...                3
# 3         What chocolate company gives you a two kiss ?                3
# 4     Whom does Uncle Stith 's girl friend , Honey ,...                3
# ...                                                 ...              ...
# 1360          Name one of King Henry Cornejo 's wives .                3
# 1361  What did Mighty Marchant always sing as he wen...                0
# 1362                What is Deshun Cage 's occupation ?                3
# 1363              What kind of business is twenty-two ?                3
# 1364  What soft drink held a national flavor poll in...                1
#
# [1365 rows x 2 columns]

# %%
augmented_train_df = augmented_train_df.rename(columns={'perturbed_text': 'text', 'perturbed_label': 'label'})
display(augmented_train_df)
augmented_train_df = augmented_train_df.reset_index()
display(augmented_train_df)
# Out:
#                                                    text  label
# 0     How can I transport files from two computer to...      0
# 1     Who are the two sons of Ozzie and Harriet Grub...      3
# 2     Who was the mother of the man who wouldn't be ...      3
# 3         What chocolate company gives you a two kiss ?      3
# 4     Whom does Uncle Stith 's girl friend , Honey ,...      3
# ...                                                 ...    ...
# 1360          Name one of King Henry Cornejo 's wives .      3
# 1361  What did Mighty Marchant always sing as he wen...      0
# 1362                What is Deshun Cage 's occupation ?      3
# 1363              What kind of business is twenty-two ?      3
# 1364  What soft drink held a national flavor poll in...      1
#
# [1365 rows x 2 columns]
#       index                                               text  label
# 0         0  How can I transport files from two computer to...      0
# 1         1  Who are the two sons of Ozzie and Harriet Grub...      3
# 2         2  Who was the mother of the man who wouldn't be ...      3
# 3         3      What chocolate company gives you a two kiss ?      3
# 4         4  Whom does Uncle Stith 's girl friend , Honey ,...      3
# ...     ...                                                ...    ...
# 1360   1360          Name one of King Henry Cornejo 's wives .      3
# 1361   1361  What did Mighty Marchant always sing as he wen...      0
# 1362   1362                What is Deshun Cage 's occupation ?      3
# 1363   1363              What kind of business is twenty-two ?      3
# 1364   1364  What soft drink held a national flavor poll in...      1
#
# [1365 rows x 3 columns]

# %%
train_dataset_df = pd.concat([original_train_df, augmented_train_df], axis=0)
train_dataset_df = train_dataset_df.reset_index()
display(train_dataset_df)
# Out:
#       level_0  label                                               text  \
# 0           0      0  How can I transport files from one computer to...
# 1           1      3  Who are the two sons of Ozzie and Harriet Nels...
# 2           2      2                           What does pH stand for ?
# 3           3      4    How many people does Honda employ in the U.S. ?
# 4           4      1  What newspaper returned a Pulitzer Prize for t...
# ...       ...    ...                                                ...
# 5860     1360      3          Name one of King Henry Cornejo 's wives .
# 5861     1361      0  What did Mighty Marchant always sing as he wen...
# 5862     1362      3                What is Deshun Cage 's occupation ?
# 5863     1363      3              What kind of business is twenty-two ?
# 5864     1364      1  What soft drink held a national flavor poll in...
#
#        index
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 5860  1360.0
# 5861  1361.0
# 5862  1362.0
# 5863  1363.0
# 5864  1364.0
#
# [5865 rows x 4 columns]

# %%
drop_col = ['level_0', 'index']
train_dataset_df = train_dataset_df.drop(drop_col, axis=1)
display(train_dataset_df)
# Out:
#       label                                               text
# 0         0  How can I transport files from one computer to...
# 1         3  Who are the two sons of Ozzie and Harriet Nels...
# 2         2                           What does pH stand for ?
# 3         4    How many people does Honda employ in the U.S. ?
# 4         1  What newspaper returned a Pulitzer Prize for t...
# ...     ...                                                ...
# 5860      3          Name one of King Henry Cornejo 's wives .
# 5861      0  What did Mighty Marchant always sing as he wen...
# 5862      3                What is Deshun Cage 's occupation ?
# 5863      3              What kind of business is twenty-two ?
# 5864      1  What soft drink held a national flavor poll in...
#
# [5865 rows x 2 columns]

# %%
display(train_dataset_df)
# Out:
#       label                                               text
# 0         0  How can I transport files from one computer to...
# 1         3  Who are the two sons of Ozzie and Harriet Nels...
# 2         2                           What does pH stand for ?
# 3         4    How many people does Honda employ in the U.S. ?
# 4         1  What newspaper returned a Pulitzer Prize for t...
# ...     ...                                                ...
# 5860      3          Name one of King Henry Cornejo 's wives .
# 5861      0  What did Mighty Marchant always sing as he wen...
# 5862      3                What is Deshun Cage 's occupation ?
# 5863      3              What kind of business is twenty-two ?
# 5864      1  What soft drink held a national flavor poll in...
#
# [5865 rows x 2 columns]

# %%
from datasets import Dataset
import pandas as pd

train_ds = Dataset.from_pandas(train_dataset_df) 


display(train_ds)
display(validation_ds)
display(test_ds)
# Out:
# Dataset({
#     features: ['label', 'text'],
#     num_rows: 5865
# })
# Dataset({
#     features: ['label', 'text'],
#     num_rows: 500
# })
# Dataset({
#     features: ['label', 'text'],
#     num_rows: 500
# })

# %%
from transformers import set_seed

set_seed(42)

# %%
#defining model:
from transformers import (AutoTokenizer, 
                          AutoModelForSequenceClassification, 
                          Trainer, EarlyStoppingCallback,
                          TrainingArguments)

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

tokenize_func = lambda sentences: tokenizer(sentences['text'], 
                                            padding='max_length', truncation=True, max_length = 50)



train_dataset = train_ds.map(tokenize_func, batched=True)
val_dataset = validation_ds.map(tokenize_func, batched=True)
test_dataset = test_ds.map(tokenize_func, batched=True)

model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=6)
# Out:
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at C:\Users\DELL/.cache\huggingface\transformers\23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.2",
#   "vocab_size": 30522
# }
#
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt from cache at C:\Users\DELL/.cache\huggingface\transformers\0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer.json from cache at C:\Users\DELL/.cache\huggingface\transformers\75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json from cache at C:\Users\DELL/.cache\huggingface\transformers\8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at C:\Users\DELL/.cache\huggingface\transformers\23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.2",
#   "vocab_size": 30522
# }
#
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 52.78ba/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 91.15ba/s]
# Loading cached processed dataset at C:\Users\DELL\.cache\huggingface\datasets\trec\default\1.1.0\751da1ab101b8d297a3d6e9c79ee9b0173ff94c4497b75677b59b61d5467a9b9\cache-3eb13b9046685257.arrow
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at C:\Users\DELL/.cache\huggingface\transformers\23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.2",
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/distilbert-base-uncased/resolve/main/pytorch_model.bin from cache at C:\Users\DELL/.cache\huggingface\transformers\9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import numpy as np
from datasets import load_metric
 
def compute_metrics(eval_pred):
   load_accuracy = load_metric("accuracy")
   load_f1 = load_metric("f1")
  
   logits, labels = eval_pred
   predictions = np.argmax(logits, axis=-1)
   accuracy = load_accuracy.compute(predictions=predictions, references=labels)["accuracy"]
   f1 = load_f1.compute(predictions=predictions, references=labels, average='macro')["f1"]
   return {"accuracy": accuracy, "f1": f1}


training_args = TrainingArguments(
    output_dir=r'C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3',          # output directory
    num_train_epochs=20,              # total number of training epochs
    per_device_train_batch_size=32,  # batch size per device during training
    per_device_eval_batch_size=32,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.1,               # strength of weight decay
    
    logging_dir=r'C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\logs\CheckList\run3',            # directory for storing logs
    save_total_limit = 1,
    load_best_model_at_end=True,
    #metric_for_best_model='f1',
    evaluation_strategy='epoch',
    logging_strategy='epoch',
    save_strategy='epoch',
    gradient_accumulation_steps=2,
    learning_rate=2e-5,
)


trainer = Trainer(
    model=model, 
    args=training_args, 
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
#training:
trainer.train(ignore_keys_for_eval=['last_hidden_state', 'hidden_states', 'attentions'])
# We are going to get multiple loss values on each training step here
# Out:
# The following columns in the training set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running training *****
#   Num examples = 5865
#   Num Epochs = 20
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 2
#   Total optimization steps = 1840
#     <div>
#
#       <progress value='828' max='1840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 828/1840 02:05 < 02:34, 6.57 it/s, Epoch 9/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.747800</td>
#       <td>1.623115</td>
#       <td>0.336000</td>
#       <td>0.182537</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.271300</td>
#       <td>0.753804</td>
#       <td>0.826000</td>
#       <td>0.703001</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.515800</td>
#       <td>0.353173</td>
#       <td>0.912000</td>
#       <td>0.770486</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.261600</td>
#       <td>0.261000</td>
#       <td>0.926000</td>
#       <td>0.781669</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.152300</td>
#       <td>0.256041</td>
#       <td>0.942000</td>
#       <td>0.891738</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.091300</td>
#       <td>0.232009</td>
#       <td>0.938000</td>
#       <td>0.890936</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.058100</td>
#       <td>0.243026</td>
#       <td>0.936000</td>
#       <td>0.887391</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.035000</td>
#       <td>0.252886</td>
#       <td>0.940000</td>
#       <td>0.892036</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.019900</td>
#       <td>0.286972</td>
#       <td>0.940000</td>
#       <td>0.913473</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-92
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-92\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-92\pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-184
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-184\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-184\pytorch_model.bin
# Deleting older checkpoint [C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-92] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-276
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-276\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-276\pytorch_model.bin
# Deleting older checkpoint [C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-184] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-368
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-368\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-368\pytorch_model.bin
# Deleting older checkpoint [C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-276] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-460
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-460\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-460\pytorch_model.bin
# Deleting older checkpoint [C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-368] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-552
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-552\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-552\pytorch_model.bin
# Deleting older checkpoint [C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-460] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-644
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-644\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-644\pytorch_model.bin
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-736
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-736\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-736\pytorch_model.bin
# Deleting older checkpoint [C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-644] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-828
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-828\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-828\pytorch_model.bin
# Deleting older checkpoint [C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-736] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\checkpoint-552 (score: 0.23200853168964386).
# TrainOutput(global_step=828, training_loss=0.46147054606589716, metrics={'train_runtime': 126.2252, 'train_samples_per_second': 929.291, 'train_steps_per_second': 14.577, 'total_flos': 682889690277000.0, 'train_loss': 0.46147054606589716, 'epoch': 9.0})

# %%
#save model:
trainer.save_state()
trainer.save_model()
# Out:
# Saving model checkpoint to C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3
# Configuration saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\config.json
# Model weights saved in C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\models\CheckList\run3\pytorch_model.bin

# %%
#evaluate:
trainer.evaluate(test_dataset)
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 32
#     <div>
#
#       <progress value='16' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16/16 00:00]
#     </div>
# {'eval_loss': 0.14105567336082458,
#  'eval_accuracy': 0.968,
#  'eval_f1': 0.9424557579724361,
#  'eval_runtime': 3.6649,
#  'eval_samples_per_second': 136.431,
#  'eval_steps_per_second': 4.366,
#  'epoch': 9.0}
