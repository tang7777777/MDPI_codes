# %%
from datasets import load_dataset
from datasets import Dataset
import pandas as pd
dataset = load_dataset('trec')
#display(dataset)
dataset = dataset.remove_columns("label-fine")
#display(dataset)
dataset = dataset.rename_column("label-coarse", "label")
display(dataset)


train_validation_ds = dataset['train'].shuffle(seed=42).select([i for i in list(range(5000))])
train_ds = Dataset.from_dict(train_validation_ds[0:4500])
validation_ds = Dataset.from_dict(train_validation_ds[4500:5000])
test_ds = dataset['test'].shuffle(seed=42).select([i for i in list(range(500))])




display(train_ds)
train_df = pd.DataFrame(train_ds)
display(train_df)
# Out:
# Using custom data configuration default
# Reusing dataset trec (C:\Users\DELL\.cache\huggingface\datasets\trec\default\1.1.0\751da1ab101b8d297a3d6e9c79ee9b0173ff94c4497b75677b59b61d5467a9b9)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1001.86it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'text'],
#         num_rows: 5452
#     })
#     test: Dataset({
#         features: ['label', 'text'],
#         num_rows: 500
#     })
# })
# Loading cached shuffled indices for dataset at C:\Users\DELL\.cache\huggingface\datasets\trec\default\1.1.0\751da1ab101b8d297a3d6e9c79ee9b0173ff94c4497b75677b59b61d5467a9b9\cache-bc761497303cb1ab.arrow
# Loading cached shuffled indices for dataset at C:\Users\DELL\.cache\huggingface\datasets\trec\default\1.1.0\751da1ab101b8d297a3d6e9c79ee9b0173ff94c4497b75677b59b61d5467a9b9\cache-d432b7eeb4042bcd.arrow
# Dataset({
#     features: ['label', 'text'],
#     num_rows: 4500
# })
#       label                                               text
# 0         0  How can I transport files from one computer to...
# 1         3  Who are the two sons of Ozzie and Harriet Nels...
# 2         2                           What does pH stand for ?
# 3         4    How many people does Honda employ in the U.S. ?
# 4         1  What newspaper returned a Pulitzer Prize for t...
# ...     ...                                                ...
# 4495      1  What does Final Four refer to in the sports wo...
# 4496      3              What is Nicholas Cage 's occupation ?
# 4497      1  In order from the top , the four stripes on a ...
# 4498      3                What kind of business is 7-Eleven ?
# 4499      1  What soft drink held a national flavor poll in...
#
# [4500 rows x 2 columns]

# %%
#wordnet part
import nltk
#nltk.download('omw-1.4')
from nltk.corpus import wordnet


from senticnet.senticnet import SenticNet
import pandas as pd

import spacy
from spacy import displacy
from lemminflect import getInflection

# %%
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.constraints.pre_transformation import RepeatModification
from textattack.constraints.pre_transformation import StopwordModification
from textattack.constraints.grammaticality.part_of_speech import PartOfSpeech
from textattack.constraints.semantics.bert_score import BERTScore

from textattack.augmentation import Augmenter
from textattack.augmentation.recipes import EasyDataAugmenter





# Create augmenter with specified parameters
augmenter = EasyDataAugmenter(pct_words_to_swap=0.1, transformations_per_example=1)
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Augment!
# additional parameters can be modified if not during initiation




def results_list_creation(s):
    try:
        results = augmenter.augment(s)
        
    
    except Exception as e:
        results = ['Error occured in text generation .']
    
    return results

import time
from multiprocessing import Pool
from concurrent import futures

time_sta = time.perf_counter()
results_list = []

#print(list(train_df['text']))

with futures.ThreadPoolExecutor() as executor:
    results_list_itera = executor.map(results_list_creation, list(train_df['text'])) 

for results in results_list_itera:
    results_list.append(results)



time_end = time.perf_counter()
tim = time_end - time_sta

# %%
print(tim/3600)
# Out:
# 0.03917798288888889

# %%
display(results_list)
# Out:
# [['How can I files transport from one computer to another ?'],
#  ['Who are the two sons of Ozzie and Harriet nelson ?'],
#  ['What does stand pH for ?'],
#  ['How many people does Honda employ in In the U.S. ?'],
#  ["What newspaper returned a Pulitzer for the fraudulent story Jimmy 's World ?"],
#  ['What two cities usually mark the extremes of English swims Channel ?'],
#  ['was the mother of the man who would not be king , the duke of Windsor ?'],
#  ['What chocolate company gives you a one-pound ?'],
#  ['What is the temperature for ready ?'],
#  ['Cross the Islamic counterpart to the Red Name .'],
#  ['What are my legal rights repossession an automobile in in California ?'],
#  ['Where was helium first discovered , hence name ?'],
#  ["Whom does Uncle Duke 's girl with , Honey , room friend ?"],
#  ['invented television ?'],
#  ['What James Michener book is subtitled Spanish Travels and expression ?'],
#  ['What does for stand laser ?'],
#  ['What is the Homelite page. home Inc ?'],
#  ["What are A two cities in Dicken 's `` the Tale of Two Cities '' ?"],
#  ['Who led engagement the Normans to victory in the Battle of Hastings ?'],
#  ['Who was the arcsecond man to walk on the moon ?'],
#  ['What canal does the ferrying Thatcher Ferry Bridge span ?'],
#  ['What foretell is the fear of cockroaches called ?'],
#  ["Which hair care product told us `` hate that gray , intersection wash it away '' ?"],
#  ['What is the web address of the list of e-mail addresses of member of the House of Representatives ?'],
#  ['How often money did the Marcos steal from their country ?'],
#  ['What is the habitat of the chickadee ?'],
#  ['How do reference a website ?'],
#  ['What is the most popular sports car distort color ?'],
#  ['What phone number can call to have a tree planted ?'],
#  ['VCR does What stand for ?'],
#  ["Where does Ray Bradbury 's Chronicles charter place ?"],
#  ["How many tenths of the 's surface lie under water ?"],
#  ['What U.s. state includes the San Juan Islands ?'],
#  ['for is a term What behavior , appearance , or expression that violates the accepted standards of sexual morality ?'],
#  ['Who is the man behind the pig-the who pulls the strings and speaks for Miss Piggy ?'],
#  ['What 1895 H.K. Wells novel was written under the title The Chronic Argonauts ?'],
#  ['What is the flick movie Jonathan Livingstone Seagull ?'],
#  ['Where can I find all information I need to know about the English Civil War , 1642-1649 , ?'],
#  ["What President once told Gene wife : `` Please give my regards to your Autry Dale '' ?"],
#  ['From what campaign does tuberculosis stem ?'],
#  ['What is a fear everything of ?'],
#  ['What is Mo molybdenum ?'],
#  ["personify What mystery writer penned `` ...the glory that was Greece , and the grandeur that was Rome '' ?"],
#  ["What U.S. city 'gateway s skyline boasts the Gateway Arch ?"],
#  ['Name the poet of the poem which begins : I do not know about gods ; but I think that the river a strong brown god-sullen , and untamed ?'],
#  ['submit What year did Montana become a state ?'],
#  ["What are the world 's three largest , in order of size ?"],
#  ['What is the only primate to lack pigment in the palms of its men ?'],
#  ['do eyes sometimes look red in photographs ?'],
#  ['Who the the first person to study was stars ?'],
#  ["actress starred in `` The Lion in Winter '' ?"],
#  ['What does it take lease to become a lawyer ?'],
#  ['What food Polo Marco did introduce into Italy from the court of Kubla Khan ?'],
#  ['represent What generation am I in ?'],
#  ['What is InterLata Internet service ?'],
#  ['How people in Tucson ?'],
#  ['Who in the richest person is the world ?'],
#  ['What is the temperature now ?'],
#  ['What brand of white rum marque is still made in Cuba ?'],
#  ['Winnie the Pooh what kind of animal ?'],
#  ['What foods contain the most ?'],
#  ['What is criticism ?'],
#  ['Who The Collector ?'],
#  ["Independent silversmith 's account for what percentage of eloquent production ?"],
#  ['How many megawatts will the power project in Indonesia , built In by a consortium headed by Mission Energy of US , produce ?'],
#  ['real is What time processing ?'],
#  ["oil cooking What has `` corn goodness '' ?"],
#  ["What 's the international radio code word for the missive F ?"],
#  ['What were the traditions like during the Elizabethian times ?'],
#  ['What will the increase be in the California brag tax by 2000 ?'],
#  ['What is the treatment for Depression ?'],
#  ['How many meters are in a mi ?'],
#  ['Herculoids the two blob members of the animated Name .'],
#  ['Who banned Peter Rose from baseball along for betting on games ?'],
#  ['in can I get started How writing for television ?'],
#  ["What are net the numbers that fit into Fermont 's last theorem ?"],
#  ["Who 's the Olympic man to have won the only decathlon twice ?"],
#  ['How can you online contact play producers and promoters on-line ?'],
#  ['What year did stockings first go on sale ?'],
#  ['Why was Muhammad Ali rifle stripped of his title and barred from boxing in 1967 ?'],
#  ['What the Golden Rule ?'],
#  ['Why are the ears your center of Libra ?'],
#  ['Why olive are there olives in martinis ?'],
#  ['moonshine What happened to Moon Maiden ?'],
#  ['What does NECROSIS ?'],
#  ['does verdandi mean ?'],
#  ['How long does it the typical American to eat 23 quarts of ice cream ?'],
#  ['do you make a computer chip ?'],
#  ['created Dennis the Menace ?'],
#  ['What does an irate car owner call iron possessor oxide ?'],
#  ['What chapter of the Book has the most verses ?'],
#  ['How many fiddlers did Old queen Cole have ?'],
#  ["south What caused Harry Houdini 's death ?"],
#  ['What state are you in if you woo in the Wu dialect ?'],
#  ['Jude Law acted in film ?'],
#  ['What was the Long March in Cathay China ?'],
#  ['long was the longest hiccup attack ?'],
#  ['What is the rarest mint ?'],
#  ['The major league baseball team in Pittsburgh is bid what ?'],
#  ['What are some of the significant historical events of the nineties ?'],
#  ['How long it take for a $ savings bond to mature ?'],
#  ['is What the largest natural lake in Pennsylvania ?'],
#  ['Olestra is What ?'],
#  ['What is a honest book to read for people who hate to read ?'],
#  ['Who is inter in the great pyramid of Giza ?'],
#  ['curious was Curious George Why ?'],
#  ['What is the length of border between the duration Ukraine and Russia ?'],
#  ['of is the daily requirement What folic acid for an expectant mother ?'],
#  ['Who sued the Dannon yougurt company for habituate a character named Ron Raider for promotion ?'],
#  ['Who at lives 24 Sussex Drive , Ottawa ?'],
#  ['How screening silk is done ?'],
#  ['Where I can find a picture of a Blue Meanie ?'],
#  ['What is the shuttle of the horsepower boosters ?'],
#  ['Who New Brave wrote World ?'],
#  ['dumbfound What does Visine get out ?'],
#  ['How does a rainbow grade ?'],
#  ['What thank the origin of is you notes ?'],
#  ['What group asked the musical Do You Believe in Magic ?'],
#  ['Who taught Matt Murdock to utilize his extraordinary abilities in Marvel comics ?'],
#  ['What is the best distance education or college ?'],
#  ['Who told all in ball Four ?'],
#  ["What 's the word for broken glass or sharp rocks embedded in cement top of a wall ?"],
#  ['How does a hurricane form ?'],
#  ['How much will the California be in the twelvemonth 2000 ?'],
#  ['When was the first Barbie ?'],
#  ['Who is Colin WHO Powell ?'],
#  ['did CNN go on the air ?'],
#  ["What is the protagonist 's figure in Dostoevski 's `` The Idiot '' ?"],
#  ["Which Ventura County police department seized the largest cocaine shipment in it ' history ?"],
#  ['What Doegs ?'],
#  ['What does warner Warner Bros. call a flightless cuckoo ?'],
#  ['What term does a Czech usage to describe a Pole ?'],
#  ['Where can I find information on the Narragansett Indians and other kindred in Rhode Island ?'],
#  ['What is a urologist ?'],
#  ["What two American countries do n't border Brazil ?"],
#  ['When did Fraze get his the patent for first pull-tab can ?'],
#  ['When did the Americans leave Vietnam ?'],
#  ['What inaugurated Pope Vatican International Radio ?'],
#  ['Who Lacan was ?'],
#  ['What are the top 5 fiction books of all clip ?'],
#  ['How do wasps make nests ?'],
#  ['What is another Son for diet ?'],
#  ["What is Steve sulfur Rogers 's profession when he 's not Captain America ?"],
#  ['How far is from Moscow ?'],
#  ['Who was first President to appoint a woman to head a cabinet ?'],
#  ["What 's the appoint of the star of the cooking show , `` Galloping Gourmet '' ?"],
#  ['Who invented WHO the electric guitar ?'],
#  ['made Stonehenge ?'],
#  ['is What ethylene ?'],
#  ['What does the name mean ?'],
#  ['What capital is build around Monument Circle which contains soldiers and sailors monument ?'],
#  ['What ocean was Amelia flying Earhart over when she disappeared ?'],
#  ['How many times a day does the typical person get to the bathroom ?'],
#  ['induce What crop failure caused the Irish Famine ?'],
#  ['What makes Black Hills , South Dakota draw a tourist attraction ?'],
#  ['Who for the Seven Mules block did ?'],
#  ['How many people on the ground were killed from Lockerbie bombing of Pan Am Flight 103 over the , Scotland , December 21 , CD .'],
#  ['What is the probability that at least ii out of 25 people will have the same birthday ?'],
#  ['What makes hamburgers taste like ?'],
#  ['What the name for clouds that produce rain ?'],
#  ['What title did Suzette Carolus assume for two months in 1984 ?'],
#  ["Who portrayed Hammer in Dracula Studios ' films ?"],
#  ['What should you yell to IN hail a taxi in Madrid ?'],
#  ['What can be set about snoring ?'],
#  ['Who the top 10 richest people in the world ?'],
#  ['What university football team did O.do J. Simpson take to the Rose Bowl ?'],
#  ['What is the approximate population of Las Vegas ,.M ?'],
#  ['Who did Bobby Fischer beat to win the bobby world chess championship ?'],
#  ["What is the abbreviation of the company name ` call General Motors ' ?"],
#  ['Why do some people have two citizenry different color eyes ?'],
#  ['good are mosquitoes ?'],
#  ['What does hazmat support for ?'],
#  ['What can communications propose satellites offer yachts ?'],
#  ['Who played Lucas McCain on rifleman The Rifleman ?'],
#  ['What U.S. state has sagebrush as its posit flower ?'],
#  ["Where can I find a person 's address from a telephone total ?"],
#  ['What happens when lightning strikes a body of ?'],
#  ['Mount did When St. Helens last erupt ?'],
#  ['What do you that a date call contains sequencing numbers , like 9-8-98 ?'],
#  ["What 's the literary term play a for on words ?"],
#  ['What was known as Spice Island ?'],
#  ["What country buys 25 percent of world 's tea exports ?"],
#  ['two presidents of the U.S. published books of poetry ?'],
#  ['embody What relative of the racoon is sometimes known as the cat-bear ?'],
#  ["What is main reason for that electric vehicles can 't nowadays popular be ?"],
#  ["Who cork `` What contemptible scoundrel stole the said from my lunch ? ''"],
#  ['What indoor sport saw the Phoenix Inferno become the Phoenix Pride on July XIV , 1983 , when the temperature pip 111 degrees ?'],
#  ['Name two actress daughters of John Mills .'],
#  ['What is Sinn Fein ?'],
#  ['What is the difference betwixt between a median and a mean ?'],
#  ['Silly putty was manufacture invented by whom ?'],
#  ['Where are the John in Saint apartments , New Brunswick ?'],
#  ['How many home runs did Lou Gehrig have during his career ?'],
#  ["What Space the name of the computer in ` 2001 : A was Odyssey ' ?"],
#  ['How many Americans oppose for the British in the American Revolution ?'],
#  ['run What did the Yalta Conference lead to ?'],
#  ['What city in Florida is Sea World FL in ?'],
#  ["What is the `` coppertop '' battery ?"],
#  ['What is the city in which Maurizio Pellegrin lives called ?'],
#  ['Who was considered the be to father of psychology ?'],
#  ['What are the four natural aids used in disembarrass a horse ?'],
#  ['many elephants are left on earth ?'],
#  ['Who is always trying get the rent from Andy Capp ?'],
#  ['How did P.T. Barnum flier the diminutive Charles S. Stratton ?'],
#  ['What crooner joined link The Andrews Sisters for Pistol Packin Mama ?'],
#  ["How many `` No '' solvent was the What 's My Line ? panel allowed ?"],
#  ['What country has the mellow arson rate ?'],
#  ['What is capital the greatest hiking Web site ?'],
#  ['At what age did opera stop writing Rossini ?'],
#  ['Who bestowed great upon Captain Britain ?'],
#  ["What is California 's uppercase ?"],
#  ['What was expire the name of the orca that died of a fungal infection ?'],
#  ['How many CDs has Garth Brooks cd sold ?'],
#  ['Give a reason for train American Indians oftentimes dropping out of school .'],
#  ['that are the diseases What can be cured by black cumin ?'],
#  ['Name fast food chain with the golden arches .'],
#  ['What is the most to way efficient start a barbeque ?'],
#  ["What is the doll of the company that manufactures the `` American Girl '' name collection ?"],
#  ['How practically much waste does an average dairy cow produce in a day ?'],
#  ['What uracil.S. state has the second-longest coastline ?'],
#  ["What 's the of name Pittsburgh 's baseball team ?"],
#  ["How many chairs are shown in Vincent Van Gogh 's 188 work The Artist 's artist Room in Arles ?"],
#  ['What is Daxam connection between New Krypton and the ?'],
#  ['the are all the southern states of What United States ?'],
#  ['What London museum features angstrom a Chamber of Horrors ?'],
#  ['morale are the best ways to improve employee What at low cost ?'],
#  ['What book is subtitled The Preservation of Favoured hotfoot in the Struggle for Life ?'],
#  ['with did the only repealed amendment to the U.S. Constitution deal What ?'],
#  ['How many bails are there in cricket wicket ?'],
#  ['How many commonwealth did Richard Nixon carry in 1972 ?'],
#  ['What is a movie that exist Kevin Costner made about Sioux Indians ?'],
#  ["s were John F. Kennedy 'Who dogs ?"],
#  ["Why can 't women dish in the Navy on board submarines ?"],
#  ['What is marble tumbled ?'],
#  ['How high must a mountain be to be address a mountain ?'],
#  ["Who is Rocky ' and Bullwinkle 's ever-lost friend ?"],
#  ['What is the per-capita Colombia of income , South America , ?'],
#  ['What college inspire Hanover , New Hampshire ?'],
#  ['How long a dog sleep ?'],
#  ['What are the four lot largest mountain ranges on the Asian continent ?'],
#  ['What two vessels between the first sea battle fought iron-covered ships ?'],
#  ['What were millions of kids wearing on their fountainhead in 1955 ?'],
#  ['What a phobophobe fear ?'],
#  ['embody How many casinos are in Atlantic City , NJ ?'],
#  ['Where is represent the Kalahari desert ?'],
#  ['How do you realise make a million bucks ?'],
#  ['What are the titles of R-Rated Sony Playstation games ?'],
#  ['What color is the stripe along each side of salmon Coho a ?'],
#  ['What is a of fear machinery ?'],
#  ['What was the name of follow the lawyer who represented Randy Steven Craft ?'],
#  ['comes English word What from the Old French covrefeu , meaning cover fire ?'],
#  ["What was Darth Vader 's son discover ?"],
#  ['How many American are stationed in South Korea ?'],
#  ['What is drought ?'],
#  ["What the address of the famous Mexican star `` Thalia '' ?"],
#  ['What is the name of the Michelangelo painting that shows two hands fingers touching ?'],
#  ['What two countries contain Sierra Nevada stop mountains ?'],
#  ['When did the Dow start reach ?'],
#  ['terrorist What group was headed by Donald DeFreeze ?'],
#  ['What level of governing government or governmental agency is responsible for dealing with racism ?'],
#  ['What on kissed the Queen Mother president the lips ?'],
#  ['Who invented the fount ?'],
#  ['What musical instrument did Holmes play ?'],
#  ['Where did the of the Bulge take place ?'],
#  ['What line insignificant of candy products included Super Skrunch and Peanut Butter Oompas ?'],
#  ['How does the Elongated world know a mystery is afoot ?'],
#  ["What award is the `` Oscar '' advertising ?"],
#  ['Which Mercury of the original seven one program astronauts did not fly on any of the Mercury flights ?'],
#  ["Name King Arthur 's sword ?"],
#  ['How is light ?'],
#  ["How large is Missouri ' population ?"],
#  ["What are the powerfulness and weaknesses of Green Lantern 's ring ?"],
#  ["What double talking `` professor '' sustain holds a doctorate in Nothing ?"],
#  ["What percentage of children between the ages of two years and eleven watch ` The Simpsons ' ?"],
#  ['When will the millennium volition officially begin ?'],
#  ['Who won the 1967 Academy Award Best for Actor ?'],
#  ['When was hurricane Hugo ?'],
#  ['What is fear of water ?'],
#  ['What President lived astatine at 219 North Delaware Street , Independence , Missouri ?'],
#  ['What do insects do through their ?'],
#  ['Shimerda My Antonia , how is Mr. In out of place on the farm ?'],
#  ['How much folic acid should a pregnant woman stimulate each day ?'],
#  ['Who was attorney the lawyer who represented Randy Steven Craft ?'],
#  ["How does the `` Zapper '' work ?"],
#  ['invented Who the paper clip ?'],
#  ['night is a fear of What or darkness ?'],
#  ['How long ago was the vs Roe. Wade decision by the Supreme Court ?'],
#  ['What is the delegacy of Nike ?'],
#  ["When was Taiwan 's first nuclear test ?"],
#  ['What author was appointed U.S. 1842 to Spain in ambassador ?'],
#  ['What are the statistic for drunken drivers in Maryland ?'],
#  ['Who automobile the rotary engine made ?'],
#  ['What is the legal blood limit for the state of California ?'],
#  ['When Taiwan did Nixon visit China ?'],
#  ["What ' the name of Jacques Cousteau 's research ship ?"],
#  ['How did Super President gain his powers on the increase animated series ?'],
#  ['What is the fastest-growing comic strip of all comedian time ?'],
#  ['What is it to like experience a near death episode ?'],
#  ['How energy is released when oxygen and hydrogen mix ?'],
#  ['In what ways did IV Ivan support Russian expansion ?'],
#  ["What is 's secret identity ?"],
#  ['is What goldenseal ?'],
#  ['Where is the Davy actress , Marion Davies , buried ?'],
#  ['What the is most radioactive food ?'],
#  ['What axerophthol is a fear of punishment ?'],
#  ["and army 's motto is Blood What Fire ?"],
#  ['How did names about come ?'],
#  ['is Where Burma ?'],
#  ['What in the U.S. experienced the most growth recently ?'],
#  ['How do top get to the you of the Eiffel Tower ?'],
#  ['How did Lee cause Harvey Oswald purchase his rifle ?'],
#  ['In what religion was ISI the nature goddess ?'],
#  ['What U.S. President designate a fondness for munching on bee pollen bars ?'],
#  ["What 's the Southern dish made of pigs ' intestines ?"],
#  ['Where site I find an Ask An Expert can ?'],
#  ['How do tell your parents you are dating an older man ?'],
#  ['Who holds the career record for the most major league runs ?'],
#  ['How many consequence events make up the decathlon ?'],
#  ['What are the top five oil-producing countries in the indium world ?'],
#  ['How do I find info about Rice importers in the world ?'],
#  ['How long it take the Milky Way Galaxy to make one revolution ?'],
#  ["it the song `` Yankee Doodle , '' why did Yankee Doodle stick a feather in his cap and call In macaroni ?"],
#  ['What of holds the record for the most appearances on the cover actress Life ?'],
#  ['What is a reliable site that can download Heretic 2 ?'],
#  ['What is the largest museum in world the ?'],
#  ['What party was Winston of a member Churchill ?'],
#  ['What are the England of New snakes ?'],
#  ['is state What Mount McKinley in ?'],
#  ['What is fear a of rejection ?'],
#  ['How much money does a back injury lawsuit generate ?'],
#  ['How is carbon dioxide removed from natural ?'],
#  ["What the only substance that gives food its `` taste '' when eaten ?"],
#  ["What 's the supreme policy-making bureau of the Soviet Communist Party ?"],
#  ["Who the `` portrayed man without a face '' in the movie of the same name ?"],
#  ['What represent is RCD ?'],
#  ['What clause in the U.sulphur. Constitution may not be changed , altered or amended ?'],
#  ["`` first-aid product What Helps the hurt stop hurting '' ?"],
#  ['does What a topophobic actor suffer from ?'],
#  ['embody What is a fear of clouds ?'],
#  ['Where I take a test that will tell me what I should be when I grow up ?'],
#  ['What is the abbreviated term used for the national Bureau of Investigation ?'],
#  ["In Sinclair Lewis ' `` Main Street , '' what was American name of the typical the town ?"],
#  ["for 's nature 's purpose What tornadoes ?"],
#  ['soft What drink is most heavily caffeinated ?'],
#  ['How many times in was 16-year National Basketball Associaton career his John Havlicek a member of the all-star team ?'],
#  ['personal is the first What computer company ?'],
#  ['What is a firewall ?'],
#  ['How many people died when the sank in 1994 ?'],
#  ['When was Babe Ruth ?'],
#  ["Nebraska is What 's most valuable resource ?"],
#  ['What California bridge was Don Brown the start to cross , on May 27 , 1937 ?'],
#  ['bone do doctors diagnose How cancer ?'],
#  ['write did Shostakovich What for Rostropovich ?'],
#  ['What is the name the planet that the Ewoks live on ?'],
#  ['How much stronger is the new vitreous carbon material invented by the Tokyo Institute of Technology compared with the from cellulose ?'],
#  ['What does stand for ?'],
#  ['What baseball known was player as Charley Hustle ?'],
#  ['What European city Nicois live in ?'],
#  ["Why is the articulate `` abbreviation '' so long ?"],
#  ['How many islands hit up Antigua ?'],
#  ["What U.S. vice-president once declared : `` If you 've seen i slum , you 've seen them all '' ?"],
#  ["What 's the name of tomcat Sawyer 's aunt with whom he lives ?"],
#  ['How do you become go a dentist ?'],
#  ['is the average hourly rate of American workers ?'],
#  ['What are the 7 Wonders of the earth ?'],
#  ['The Jewish ABC is known as what ?'],
#  ['What is the grim level of the American judiciary ?'],
#  ['three are the What most populated countries in the world ?'],
#  ['What South American country won its first World soccer title in 1978 ?'],
#  ['personify What are liver enzymes ?'],
#  ['What is a valve heart leaky ?'],
#  ['Hitler came to power in Germany what year ?'],
#  ['Who missions Space Ghost on his accompanied ?'],
#  ['What Louisiana Senator won a seat been had that held by his father and mother ?'],
#  ['Who played the title role in The Englishwoman Romantic ?'],
#  ['What is the parentage of the word assassinate ?'],
#  ['What did the Confederate Constitution read say about slavery ?'],
#  ['What killed Bob bobtail Marley ?'],
#  ['What the name Melissa mean ?'],
#  ['What is Jell-O ca-ca from ?'],
#  ['How did shipyard inspector James J. Kilroy indicate equipment as being satisfactory ?'],
#  ['What , s , appear on boxes of Kodak film ?'],
#  ['What penalty space lies avenue between Baltic Avenue and Reading Railroad on a Monopoly board ?'],
#  ['What type did Tex Avery first create upon arriving at MGM ?'],
#  ["Who realm DC Comics ' protects of dreams ?"],
#  ['What was the only country you were WA allowed to drive into Israel from in 1979 ?'],
#  ['In the Miller Lite represent TV commercial , who is the creature ?'],
#  ['U.S. state is Dixville Notch in ?'],
#  ['What Kennedy to married was Ethel ?'],
#  ['are What dingoes ?'],
#  ["What 's of official language the Algeria ?"],
#  ['How can SQL queries be ?'],
#  ['What ill-fated craft was Lehmann by Ernst captained ?'],
#  ['What painter popularized cans and Brillo soap pad boxes ?'],
#  ['How many clock was pitcher , Warren Spahn , a 20-game winner in his 21 major league seasons ?'],
#  ["Who was Ben Casey 's Bos ?"],
#  ['What are the developmental stages of swimmer ?'],
#  ['Who wrote the sci-fi trilogy Foundation , Foundation and Empire , understructure and Second Foundation ?'],
#  ['When was John D. john Rockefeller born ?'],
#  ["the sings Who song `` Drink to me with thine eyes '' by Ben Johnson ?"],
#  ['Where can I encounter a website that gives comparisons of good prices ?'],
#  ['What relative of Leo Tolstoy translated War and eight times ?'],
#  ["What race brought about the Inhumans on Marvel 's Earth ?"],
#  ["What is Li 'lastly l Abner 's last name ?"],
#  ['How of them are in sub-Saharan Africa ?'],
#  ['What is a be heuristic ?'],
#  ["Where the official `` zero '' of the sea level ?"],
#  ["Theses did Luther display his `` Ninety-Five Where '' ?"],
#  ["What city 's theatrical district been dubbed The Roaring Forties ?"],
#  ['How many lemurs of types are there ?'],
#  ['How come out bulbs go light ?'],
#  ['What state in the U.S. the most blacks ?'],
#  ['Why does a wick need a candle ?'],
#  ['How ago did the Anglican church part from the Vatican ?'],
#  ['How can you stop the itch from itchiness poison ivy ?'],
#  ['What the Peloponnesian League ?'],
#  ["What is Megan 's constabulary ?"],
#  ['What seven digits follow the area the in code number for long distance information ?'],
#  ['What category does the color pink denote the in Trivial Pursuit Baby Boomer Edition ?'],
#  ['What famous soldier was born in Europe , died in Asia , and was laid to lie in Africa ?'],
#  ['Where does the U.S. rank among cosmos countries in area ?'],
#  ['What scale touchstone earthquakes ?'],
#  ['What is largest island in the Mediterranean Sea ?'],
#  ['was Where the Cisalpine Republic , 1797-185 , ?'],
#  ['What revere is a fear of women ?'],
#  ['How does kink hair curl ?'],
#  ['Which gender has freehanded thighs ?'],
#  ["What `` melts in in mouth , not your your hands '' ."],
#  ["What is Grenada 's primary commodity export ?"],
#  ['What want a woman does ?'],
#  ["What city has the world 's farseeing subway system ?"],
#  ['What is carpal burrow syndrome ?'],
#  ['What international sport was originally hurley ?'],
#  ['What U.S. vice president was once and acquitted for treason in a plot to set up his own independent empire in the West ?'],
#  ['does a collier mine ?'],
#  ['What surrounds the Cayman Islands ?'],
#  ['How do you accost a Chinese person ?'],
#  ['When did and art Gothic architecture flourish ?'],
#  ['Who Quetzalcoatl ?'],
#  ['AN What is an annotated bibliography ?'],
#  ['How many embody years is Johnnie Walker Black Label aged ?'],
#  ['Where is Bend South ?'],
#  ['What which the name of the medical condition in is a baby is born without a brain ?'],
#  ['Where can I find the best evidence free for debate about Russia ?'],
#  ['What is the history of Spartacus , Romanic the Roman slave and gladiator ?'],
#  ['Where is Webster university ?'],
#  ["Where in the Bible does it tell about Jesus Christ 's crony and sisters ?"],
#  ['Why serve do they sterilize the needle for lethal injection ?'],
#  ['In what year was the movie the Ten Commandments liberate ?'],
#  ['interchange How often are brain cells replaced ?'],
#  ["What famous New York City mayor wrote the hit song , `` Will You Love Me in December as a You Do in May ? ''"],
#  ['What mean JESSICA does ?'],
#  ["What is `` for soft drink the adults '' ?"],
#  ['received the Will Rogers Award in 1989 ?'],
#  ['Where are diamond mined ?'],
#  ["How Alaska is the Arctic refuge to preserve unique wildlife and wilderness value on large 's north coast ?"],
#  ['What is a fear ruin of ?'],
#  ['How wide is the Atlantic sea ?'],
#  ['of is a fear What cold ?'],
#  ['How many warmup pitches does a reliever get coming into a baseball spunky ?'],
#  ['What ill-fated American general dragged a bull terrier named Willie through War II ?'],
#  ["What is the Viking Prince 's first embody name ?"],
#  ['What year the United States pass the Copyright law ?'],
#  ["What company was the original of TV 's Superman ?"],
#  ["Who 's baby was Sweet Pea on the Popeye WHO cartoon ?"],
#  ['What are two plants that clothes are name from ?'],
#  ['What the is population of Kansas ?'],
#  ['What percentage of the soundbox is muscle ?'],
#  ['On what continent is cost Mozambique ?'],
#  ['What is recruitment audience technique ?'],
#  ['Where does come from ?'],
#  ['What year was the NAACP ground ?'],
#  ['What hard-of earreach artist painted Sunflowers ?'],
#  ['What chemical in red good is wine for the heart and what exactly does it do to your body ?'],
#  ["What are the deuce-ace animals in Sheila Burnford 's The Incredible Journey ?"],
#  ['What causes gamey balls ?'],
#  ['broadcasting did CNN begin When ?'],
#  ['What Nun husband-and-wife team did radio ads for Blue famous wine ?'],
#  ['Who create made the first surfboard ?'],
#  ['What does the word camaro mingy , from the GM car the Camaro ?'],
#  ['Who was the only person convicted in the My Lai massacre ?'],
#  ['What is the fear of computer the called ?'],
#  ["What name did football 'in New York Titans adopt s 1963 ?"],
#  ['What the is Hub of London ?'],
#  ['What city does Airport Orly serve ?'],
#  ['How many eyes does a thrash have ?'],
#  ['How Rocky Marciano die ?'],
#  ["What was Jimmy Durante ' theme song ?"],
#  ["not meter did Shakespeare use in writing : `` To be , or What to be , that is the question.. . '' ?"],
#  ['Which sex in denied voting rights is Kuwait ?'],
#  ["When is Dick Clark ' birthday ?"],
#  ['Why did the Anglican church split the from Vatican ?'],
#  ["Which Bourbon the was restored to king French throne during Napoleon 's abdication ?"],
#  ['What Southern California town is named after a character famous by Edgar Rice Burroughs ?'],
#  ['Where is Natick ?'],
#  ['Who is seat the name of the Harvey Wallbanger drink ?'],
#  ['What are some ways help someone with Chicken Pox ?'],
#  ['What composer was awarded the Medal of Honor by Franklin viosterol. Roosevelt ?'],
#  ['What does horse Ridder publish ?'],
#  ['What hold then-derogatory term was applied to the painters Monet , Sisley , Pissarro , Renoir and Degas ?'],
#  ['What John Steinbeck novel portrays the Joad family , driven present from the Oklahoma dustbowl ?'],
#  ["What war saw battles at Parrot 's vestal Beak and Black Virgin ?"],
#  ['What minimal was the minimum wage in 1991 ?'],
#  ['What do you demand to do to marry someone in jail ?'],
#  ['What African country was constitute by freed American slaves in 1847 ?'],
#  ["How I increase my biceps ' size ?"],
#  ['What is ?'],
#  ['What follow is idealab ! ?'],
#  ['What country are you visiting if you land at Airport Duvalier President ?'],
#  ['With liken whom did Bush compare Saddam Hussein ?'],
#  ['What is the discover of the country which Hitler ruled ?'],
#  ['How long do you have to live in a last community to vote ?'],
#  ['Where did the Maya people experience ?'],
#  ['What are found in an estuary ?'],
#  ["Name IN of the powerful white trader in Conrad 's `` Heart of Darkness '' ?"],
#  ['What is a mierkat ?'],
#  ['How Marx Brothers were there ?'],
#  ["What 's serviceman 's par on a 455-yard golf hole ?"],
#  ['What are people doing to extinguishing help prevent the extinction of birds ?'],
#  ['What largest the is U.S. state east of the Mississippi ?'],
#  ['What is surroundings fear of home a ?'],
#  ['What is a country that jump with the letter x ?'],
#  ['What kind of women hold Sigmund Freud erotic dreams ?'],
#  ["a brand number graces the black label of What bottle of Jack Daniel 's ?"],
#  ['Tutu is Desmond Who ?'],
#  ['What is a pig in a biff ?'],
#  ['Where is the Kentucky Horse Park site ?'],
#  ['What is only modern language that capitalizes its singular first-person pronoun ?'],
#  ['What company is being buy by Yahoo and how much is the deal worth ?'],
#  ['What is the meaning of follow thalassemia ?'],
#  ["What 's the only discolour Johnny Cash wears on stage ?"],
#  ["northernmost 's the What U.S. state apart from Alaska ?"],
#  ['How cock-a-hoop is the universe actually ?'],
#  ['What is the name of the popular singer whose song became the theme song for a brand of catsup ?'],
#  ['What is a bone marrow ?'],
#  ["What game 's board south shows the territories of Irkutsk , Yakutsk and Kamchatka ?"],
#  ['In what year did Joe DiMaggio compile his 56-game hitting mottle ?'],
#  ['How loud is ?'],
#  ['Who stock the invented ticker in 1870 ?'],
#  ['What.S. city is The Queen of the Pacific ?'],
#  ['What are the Benelux commonwealth ?'],
#  ["Name the product that is `` at your astatine grocer 's , at your fingertips . ''"],
#  ['is What Spumante ?'],
#  ['What athlete brand the most money from sports merchandise sales ?'],
#  ['What 2 statues did France contribute to other countries ?'],
#  ['started the Dominos Pizza chain ?'],
#  ['What little boy and dog live in shoe ?'],
#  ['How many South American names have the letter Z in their countries ?'],
#  ['What baseball outcome required nine in 1879 , eight balls in 1880 and seven balls in 1881 ?'],
#  ['What the name of the American who was captured when his plane went down over Syrian-held Lebanon ?'],
#  ['What did Woody Allen claim the Japanese gangster film he dubbed into English as a comedy ?'],
#  ['What causes mouth sores in the canker ?'],
#  ['quote What do you call a book of quotes ?'],
#  ['What fuel do use airplanes ?'],
#  ['What did Cool Hand Luke to jail for ?'],
#  ['What is a fear insanity of ?'],
#  ['What was the first flavor ?'],
#  ['What game is to anybody over 21 ?'],
#  ['What Lewis Carroll book introduced Humpty Dumpty to reserve the world ?'],
#  ["is Ray Bradbury 's illustrated man illustrated with ?"],
#  ["What words in the have two u 's back to back ?"],
#  ['What does Ouija ?'],
#  ['played is spaceball What on ?'],
#  ["Who the nebbish that is Marvel 's official mascot ?"],
#  ['What product on for market is good the hiding facial scars ?'],
#  ['What are chloroplast ?'],
#  ['Shea and Gould closed their Los Angeles position for what reason ?'],
#  ["What company named i of its pens `` The Banana '' ?"],
#  ['What does Nicholas Cage do for a support ?'],
#  ['What show is the electronic device used to produce visual displays corresponding to electric signals ?'],
#  ['What ISPs be in the Caribbean ?'],
#  ["s much money are Dumbo 'How ears insured for ?"],
#  ['How can you become an FBI AN agent ?'],
#  ['Where scheme can I find a lesson plan for teaching the metric system conversion to American standard ?'],
#  ['What was the name of the 187s Irish terrorist in Pennsylvania mining areas ?'],
#  ["What is the constitute of the Family Circus 's dog ?"],
#  ['What Edmund did the month Fitzgerald sink ?'],
#  ['What was the of nickname German flying ace Manfred von Richthofen ?'],
#  ['Where can I buy a pony on daughter Big Island for my the ?'],
#  ['What of the definition is spamming ?'],
#  ['What lake in Scotland is said to one or more monsters ?'],
#  ['Approximately how many students are enrolled at the University of ?'],
#  ['What are the conjugations awake of wake and woke ?'],
#  ["What company 's logo is a `` W '' in a lap ?"],
#  ['What novel new inspired the movie BladeRunner ?'],
#  ['What is longest place name in the U.S. ?'],
#  ["plantar does `` intractable What keratoma '' mean ?"],
#  ['bouncy Where do lobsters like to live ?'],
#  ['Who played Sally on The Dick Van Dyke Show ?'],
#  ['textiles can I get cotton Where importer details ?'],
#  ['What woman has carried the multiple births , twins , triplets , etc. , ?'],
#  ['What writer-journalist made his mark colorful Broadway and underworld characters ?'],
#  ['What is the function of appendix ?'],
#  ['What sports event is Meyer Wolfsheim supposed to have desexualise in The Great Gatsby ?'],
#  ["Who is actress Goldie 's current actor boyfriend ?"],
#  ["What 's the tallest building in New City ?"],
#  ['How make years many up a lustrum ?'],
#  ['graders are some science fair projects for 8th What ?'],
#  ['bathroom Who is John Macarthur , 1767-1834 ?'],
#  ['What were the names of the three ships embody used by Columbus ?'],
#  ['What is the meaning of the list Ella ?'],
#  ['Who was the famous door-to-door salesman ?'],
#  ['is the election of a new Pope announced to the world ?'],
#  ["Who is the composer of Canon `` in D Major '' ?"],
#  ["What musical instrument did Prewitt play in to Jones 's From Here James Eternity ?"],
#  ['Where I find a case on Americans with Disabilities Act of 199 ?'],
#  ['Who the king who was forced to agree to the Magna Carta ?'],
#  ['What axerophthol is a female rabbit called ?'],
#  ['Who invented ?'],
#  ['What was the claim to of King Camp Gillette ?'],
#  ["What is New England 's highest peck ?"],
#  ['is What a multiplexer ?'],
#  ['What two nation is Andorra nestled between ?'],
#  ["What is the origin of the typing practice sentence `` Now is the time for all good men to come doom to the aid of their country '' ?"],
#  ['copier does a How work ?'],
#  ['What is the capital of cost California ?'],
#  ['historical What event happened in Dogtown in 1899 ?'],
#  ['How days does a typical mayfly live ?'],
#  ['When is the site www.questions.com going to extend open ?'],
#  ['What kind of creatures are the Canary Islands call for ?'],
#  ['How many angstrom pounds are there in a stone ?'],
#  ['Who was Garrett Morgan wed to ?'],
#  ['What is ?'],
#  ["What is Drew s 'Barrymore email address ?"],
#  ['Where is the group M People live from ?'],
#  ['How many blank follow a period at the end of a sentence ?'],
#  ["photographer author did What Yousuf Karsh call `` the shiest man I ever met '' ?"],
#  ['What was the reason for the division of the Anglican and Vatican churches ?'],
#  ['What engineer invented the pull-tab ?'],
#  ['What is the Order of the in Arrow Boy Scouts ?'],
#  ['What city would you be in if you were eating the pigeons in the Piazza San Marco ?'],
#  ['How does Cos Cob , refer CT get its name ?'],
#  ['Where is the largest post office building world the in ?'],
#  ['What game is Garry really good at ?'],
#  ['What actor learned to play the saxophone and speak Russian for a persona in a movie ?'],
#  ["What whisky the `` known by is company it keeps '' ?"],
#  ['What must a Las Vegas blackjack dealer do when reaches 16 ?'],
#  ['How do Boards work ?'],
#  ['What named are overalls for Dungri , a suburb of Bombay ?'],
#  ['What is be film noir ?'],
#  ['What have causes rust ?'],
#  ['did Peabody and Sherman travel through time ?'],
#  ["What 'green the s variety of beryl called ?"],
#  ['Windsor is Where Castle ?'],
#  ['What does appropriates money imply ?'],
#  ['Who are the the hunting and gathering tribe of nomadic Kalahari Desert in Africa ?'],
#  ['What actor first portrayed jampack Bond ?'],
#  ['What D.H. Lawrence novel originally was titled Tenderness ?'],
#  ['Amsterdam is Where ?'],
#  ['What did John Hinckley do to impress Jodie Foster ?'],
#  ['When did Israel begin turning the Gaza despoil and Jericho over to the PLO ?'],
#  ['When did place Bounty mutiny take the ?'],
#  ['Who in Emperor Palpatine played Star Wars ?'],
#  ['What kind of u puzzle first appeared in the U.S. in the New York World on December 21 , 1913 ?'],
#  ['What National League baseball team employed 72 third baseemen in its initiative 2 seasons ?'],
#  ['How is vanguard the new Ford Econoline van F25 V1 engine ?'],
#  ['Who was the first motorcoach of the Cleveland Browns ?'],
#  ["What children 's tale contains the line : `` Come , Cinderslut , hold this skein of wool for me '' ?"],
#  ["In Waugh 's `` A Handful of Dust , '' what does the mad previous man force the wedge to do every afternoon ?"],
#  ["What 's the staff of life remark in the Lord 's Prayer ?"],
#  ['S was the 1st U.Who. President ?'],
#  ["What 's destroyed in Genesis 19 : twenty-four ?"],
#  ['What does the double-O show in 007 ?'],
#  ['What does the fare name Billie mean ?'],
#  ['What Russian master spy lived in the U.S. under the name Emil Goldfus ?'],
#  ['What Polynesian people inhabit New ?'],
#  ['Who was the lawyer who represented Steven Craft ?'],
#  ['What are web good fractal some sites ?'],
#  ['What is Dakota Hills , South Black most famous for ?'],
#  ['In South Korea , how many Soldiers are there ?'],
#  ['What the saw a naval battle between the luxury liners Cap Trafalgar and war Carmania ?'],
#  ['What is the harden busiest air travel season ?'],
#  ['What is the average hours per months by online spent AOL users ?'],
#  ["Who did Doris Day mean when she said : `` I call him Ernie because come he 's certainly no Rock '' ?"],
#  ['WHO won the first World Series ?'],
#  ['What debt did Qintex group leave ?'],
#  ['What is the meaning of the name ?'],
#  ['What is the best-selling book of all metre ?'],
#  ['What lake is the source of the flannel Nile ?'],
#  ['Define Club Pheonix the ?'],
#  ['What is equal hypertext ?'],
#  ['What is a follow fear of hair ?'],
#  ['Name the tyke left on a doorstep at the beginning of Gasoline Alley .'],
#  ['FAR How far out is the universe ?'],
#  ['How many layers does a bottle of Yoo-Hoo locate into ?'],
#  ['Where in a tree does occur ?'],
#  ["south What country 's national passenger rail system is called Via ?"],
#  ['How often are IV quadruplets born ?'],
#  ['What color eyes most sensitive to light ?'],
#  ['What city hosted the first Winter Asia in Olympics ?'],
#  ['What is the origin of candy cane at Christmas ?'],
#  ['come What does 7847+5943 equal ?'],
#  ['The italian quondam artist , Maurizio Pellegrin , is how old ?'],
#  ['What a spermologer collect ?'],
#  ["What chapter Gone with the Wind has Rhett Butler leaving Scarlett O 'Hara ?"],
#  ["In what city is the noted famed St. Mark 's Square ?"],
#  ['Who wrote The mystery Life of Walter Mitty ?'],
#  ['How time you define can ?'],
#  ["What country boasts Ismail 's Palace and the Palace of King Farouk ?"],
#  ['What form kind of guitar did Jimi Hendrix play ?'],
#  ['How bikini the did bathing suite get its name ?'],
#  ['Which police department made the in biggest cocaine bust all-time Ventura County ?'],
#  ['What does adenine&W of root beer fame stand for ?'],
#  ["me said `` Give Who liberty or give me death '' ?"],
#  ['What Nevada center has been dubbed The grownup Little City in the World ?'],
#  ["What New Orleans D.A. claimed : `` My staff and I solved the cholecalciferol assassination weeks ago '' ?"],
#  ['What is Toulmin logic ?'],
#  ["Which magazine entertainment `` fine is for men '' ?"],
#  ['How many islands Fiji have ?'],
#  ["What is the name Kevin of Costner 's movie about Sioux Indians ?"],
#  ["Who said , `` I shall return . '' during World Two ?"],
#  ['What is a of failure ?'],
#  ['What attorneys work for The Center for the Defense of barren Enterprise ?'],
#  ['represent What is the origin of head lice ?'],
#  ['How heaviness does crosstalk relate to InSb thickness in infrared detectors ?'],
#  ['Microsoft is Bill Gates of What E-mail address ?'],
#  ['What was the non-fiction best-seller of 1952 , 1953 and 1954 ?'],
#  ['How many were executed in concentration camps during WWII ?'],
#  ['equal Where is Trinidad ?'],
#  ["Who diddle the cop in the movie `` Kindergarten Cop '' ?"],
#  ['CNN is owned by ?'],
#  ["WHO was the bandleader mentor of Ella Fitzgerald with whom she cowrote `` A_Tisket , A-Tasket '' ?"],
#  ["Which country is known as `` openhanded Big Bear '' ?"],
#  ["meta does the word `` What '' mean ?"],
#  ['What is the per-capita income of Colombia , South America ?'],
#  ['Where Colony can I get information on the original 13 US colonies ?'],
#  ['How tall was the animated Kong ?'],
#  ["What are faults the earth 's crust ?"],
#  ['Who wrote reckon The Look of Love after viewing Ursula Andress ?'],
#  ["Who played father on `` Charles in Charge '' ?"],
#  ['What type of in is used currency China ?'],
#  ['What film did Louise win the best actress Oscar for ?'],
#  ['Which condiment was once sold a patent medicine ?'],
#  ['niche is an ecological What ?'],
#  ['What are the constituent of polyester ?'],
#  ['What humankind percentage of American men are alcoholic ?'],
#  ['Shea and Gould had an part in Los Angeles for how long before closing it ?'],
#  ['How much time does the blinking of an eye yield ?'],
#  ['How four-handed disks does each player have in a many game of Crokinole ?'],
#  ['What war summate jeep and quisling to the English language ?'],
#  ['Who is the voice of misfire Piggy ?'],
#  ["go What is ` Last Chance for Animals ' ?"],
#  ['Where the name Daniel originate ?'],
#  ['What famed strip of land is a 15-minute boat shore trip across the Venetian Lagoon from Venice ?'],
#  ['How many ampere pairs of wings does a tsetse fly have ?'],
#  ['the what disease is For drug Sinemet used as a treatment ?'],
#  ['list a flying mammal .'],
#  ['What part John did Peter Zenger play in the deveopment of the newspaper in America ?'],
#  ['Who is the chairwoman of Pergament ?'],
#  ['What are the Arabic numeral from 1 to 10 ?'],
#  ['sneeze How long was the longest sneezing attack ?'],
#  ['Where did the myth of Santa Claus originate ?'],
#  ['Which Annamese terrorist is now a UN delegate in Doonesbury ?'],
#  ['Yes autobiography is titled Whose I Can ?'],
#  ['Who gave King the round table ?'],
#  ['How can I get some free technical information Electric Vehicle ?'],
#  ['What tastes can a human distinguish ?'],
#  ['What the average time it takes for a male to ejaculate ?'],
#  ['Who shared a Roger York City apartment with New Maris the year he hit 61 home runs ?'],
#  ["How many on are grooves a dime 's edge ?"],
#  ['What is name given to the Islamic counterpart of the Red Cross ?'],
#  ['Why did the chicken cross the dress road ?'],
#  ["What is Answers.com 's ?"],
#  ['Name Four Horsemen of the Apocalypse .'],
#  ['What class was the Avery Dennison company founded ?'],
#  ['What singer became of over the death despondent Freddie Prinze , quit show business , and then quit the business ?'],
#  ['What year did Vietnam the War end ?'],
#  ['What is the brightest star from Earth ?'],
#  ['What California bridge was Don Brown the first cross , on May 27 , 1937 ?'],
#  ['What countries does Mont Blanc Tunnel join ?'],
#  ["Who said : `` Soldiers win generals battles and the get the credit '' ?"],
#  ['Who won the Nobel peace Prize in 1991 ?'],
#  ['What is the remainder between a bottle and a jar ?'],
#  ['How many hours of work does a take it typist to complete a 100-page screenplay ?'],
#  ['What was electronics company Japanese named for a coastal city northeast of Tokyo ?'],
#  ["What classical Spanish glitters warned : `` All that writer is not gold '' ?"],
#  ["sulfur Why is Microsoft 's Windows 3 software so successful ?"],
#  ['How much calcium should an adult female have ?'],
#  ['Which killer whale died earth at Sea World of a fungal infection ?'],
#  ['henry Who did Arthur H. Bremer try to assassinate on May 15 , 1972 ?'],
#  ["What was Al Capone ' nickname ?"],
#  ['What campaign rust ?'],
#  ['the created Who character James Bond ?'],
#  ['What future movie treat was introduced to flick American colonists in 1603 by Native Americans ?'],
#  ['What Candlemas is Day ?'],
#  ['What book does In Holden Caulfield appear in ?'],
#  ['What is the name of the chronic neurological autoimmune disease which attacks the protein sheath that surrounds nerve cells causing a gradual loss of red movement in the body ?'],
#  ['What is the name of the president axerophthol of Garmat U.S.A ?'],
#  ["How many feet high is the hurdle in front of a runner 's steeplechase water leap ?"],
#  ['What famous communist leader died in croak Mexico City ?'],
#  ['is a virtual IP address ?'],
#  ['What are some fun to things do in Cozumel , Mexico for teenagers ?'],
#  ['Which college did Dikembe Mutombo play at ?'],
#  ['What of the wingspan is a condor ?'],
#  ['How much would a black-and-white 1-cent stamp be worth , Thomas along Jefferson on it ?'],
#  ['Where u was the first zoo in the U.S. ?'],
#  ['What is Nina ?'],
#  ["What 's the sequel to Alice 's in Adventures Wonderland ?"],
#  ['Where does tuberculosis number from ?'],
#  ['viscousness What is viscosity ?'],
#  ["`` Rockefeller was sometimes called Which JDR3 '' ?"],
#  ['Stuart Hamblen is believe to be the first singing cowboy of which medium ?'],
#  ["Name `` heroine in of Scruples '' ?"],
#  ['What year was the rig for American Graffiti ?'],
#  ['Amazon city is near the mouth of the What ?'],
#  ['What is an daybreak ?'],
#  ['What square is center geographical the of London ?'],
#  ['Siamese When is the Thai New Year ?'],
#  ['Who is inch the richest person in the world , without owning a business ?'],
#  ['How Socrates did die ?'],
#  ["Brandenburg was Berlin 's When gate erected ?"],
#  ['How many Canadian emmigrate each year ?'],
#  ['the is What starting salary for beginning lawyers ?'],
#  ["What two land fought the Hundred Years ' War ?"],
#  ['How old was Sir Edmund when Hillary he climbed Mt. Everest ?'],
#  ['far can a man travel in outer space ?'],
#  ['When was the world-class railroad from the east coast to the west coast completed ?'],
#  ['How many trees go paper making in a year ?'],
#  ["Who was the Columbia word-painting head who forged actor Cliff Robertson 's name on a $1 , 000 check ?"],
#  ["What cable network bills itself as `` the folk entertainer '' ?"],
#  ['What strap an arab is ?'],
#  ['What is the hypothesis theory of equivalence states ?'],
#  ['How many does an oyster have ?'],
#  ['What disease is transport by the Anopheles mosquito ?'],
#  ['Who does the spokesperson of the Simpsons ?'],
#  ["What was Edward Albee 's first run full-length play ?"],
#  ['Wyoming was the first woman governor of Who ?'],
#  ['When was locomotive the internal combustion engine developed ?'],
#  ["Who was the author of the novel `` Far From the Madding crew '' ?"],
#  ['How do single do this ?'],
#  ["Where was `` I have fallen , and I can 't get up '' said thyroxin first ?"],
#  ['What is ?'],
#  ['is the history of skateboarding ?'],
#  ['Where does Mother Angelica be ?'],
#  ['What is personify hypnotherapy ?'],
#  ["What was the constitute of Humphrey Bogart 's club in Casablanca ?"],
#  ['What is the mean income of the top 10% , represent top 5% , and top 1% ?'],
#  ['What gestate sperm up into the pelvic region ?'],
#  ["What woman was Time 's Man of the Year for ?"],
#  ['What is the name Miss of India 1994 ?'],
#  ["What was Dwight Eisenhower ' favorite card game ?"],
#  ['heavier do Why objects travel downhill faster ?'],
#  ["What.S. state 's biggest lake is Lake Sam Rayburn ?"],
#  ['Why does sound travel quicker through water air ?'],
#  ['What kind were weapons of used in Medieval warfare ?'],
#  ['How do you box geartrain train a cat ?'],
#  ['Why November the U.S. presidential elections held in are ?'],
#  ['What Nantucket divers killed more shipwreck exploring it than the 52 people it sank with ?'],
#  ['What is a fear of awe speaking ?'],
#  ['What is 55 times sweeter than cane ?'],
#  ['What mythical pattern carries an hourglass and a scythe ?'],
#  ['How many months does a last human pregnancy normal ?'],
#  ['is amezaiku ?'],
#  ['How do I to my Congressman ?'],
#  ['What have you not let a tennis ball if you volley ?'],
#  ['How does hydroelectric a dam work ?'],
#  ['is What DEET ?'],
#  ['constitute a movie that the actress , Sandra Bullock , had a role in .'],
#  ['appoint the story by Chris Van Allsburg in the which a boy tries to become a great sailor ?'],
#  ['How make you do a paintball ?'],
#  ['Where is the Henry crossing Museum ?'],
#  ['Where can unmatchable find Rider College ?'],
#  ['Which mammal last , breeds , eats , and sleeps underground ?'],
#  ['Where is the Danau ?'],
#  ['What is god name of a Greek the ?'],
#  ['What country is proud to claim Volcano national Park ?'],
#  ['How is solvent.com different from KnowPost.com ?'],
#  ["What are rivers 's two longest Britain ?"],
#  ['mention a civil war battlefield .'],
#  ['Who excogitate Make-up ?'],
#  ['What were the frozen foods ?'],
#  ['What is a Jellicle spue ?'],
#  ['What color are the the walls of castellated Kremlin ?'],
#  ['How do I know is someone truly in love with me ?'],
#  ['What botanical marvel did botanic Nebuchadnezzar build ?'],
#  ["What continent 'live s second-highest peak is Mont Blanc ?"],
#  ['Who was made the first honorary crap citizen of the U.S. ?'],
#  ['How many movies stimulate has Drew Barrymore been in ?'],
#  ["What doctor claimed in a 1946 book : `` There is no such thing as a bad son boy '' ?"],
#  ["Hamlet wrote ` Who ' ?"],
#  ['Who is section manager for guidance and organization control systems at JPL ?'],
#  ['How many sides AN does an obelisk have ?'],
#  ['How do they grow Teflon to stick to the pan ?'],
#  ['How did pee appear on the earth ?'],
#  ["What singer 's theme moonlight song was When the Moon Comes over the Mountain ?"],
#  ["On which date is Xmas the Ukrainians ' Christmas ?"],
#  ['Where the Abominable Snowman said to wander ?'],
#  ['What store does Stewart advertise for ?'],
#  ["What city 's airport is named International ?"],
#  ['What does Larry King do for a life ?'],
#  ['What kind of greeting is appropriate to ship on Yom Kippur ?'],
#  ['When does the Bible enjoin the seasons started ?'],
#  ['Where world the busiest ports in the are ?'],
#  ['What the chemicals used in glowsticks ?'],
#  ['What is ?'],
#  ['What is Pope present the named ?'],
#  ['Who was Whitcomb represent Judson ?'],
#  ['When was labor child abolished ?'],
#  ['Where did Dikembe Mutombo expire to college ?'],
#  ['do How windmills work ?'],
#  ['How many miles is it Ohio from North Carolina ?'],
#  ["What was called the world 'department largest s store ?"],
#  ["How many times a day should you take a prescription marked `` q.d.i . '' ?"],
#  ["What hair Delilah do to Samson 's did ?"],
#  ['What does it take to IT be a hero ?'],
#  ['What peter do you use to crewel ?'],
#  ['What river stream past the Temple of Karnak ?'],
#  ['is a woman most fertile ?'],
#  ["What undercut famed gangland slaughter cut into the membership of Bugs Moran 's outfit ?"],
#  ['How much pizza do Americans eat in American a day ?'],
#  ['What does hundredweight the abbreviation cwt. ?'],
#  ['What do call Japanese the Japan ?'],
#  ['What powdered soft drink mix into space ?'],
#  ['What is p.m. an for , as in 5 p.m. ?'],
#  ['On what tomcat T.V. show could Tom Terrific be found ?'],
#  ['What Colorado city own its own glacier ?'],
#  ['What ocean liner burned and sank in Hong Kong entertain harbor ?'],
#  ["Who Sherlock Holmes 's archenemy ?"],
#  ['How many inches over six is Tom Selleck ?'],
#  ['Who was the mavin witness at the Senate Watergate hearings ?'],
#  ['How deep is sound a fathom ?'],
#  ['What sport slotbacks , tailbacks , and touchbacks ?'],
#  ["What is pecker Clark 's date of birth ?"],
#  ['When are sheared sheep shorn ?'],
#  ['Name four comic strips about .'],
#  ["What former African leader moderate his country 's boxing title for nine years ?"],
#  ['find do I Where information for foreclosure properties on the Internet ?'],
#  ['Name an American motorcycle .'],
#  ['Who was and lyricist the who was the composer between Gilbert and Sullivan ?'],
#  ['How many GE were there on the original minutes College Bowl clock ?'],
#  ['The second most popular sport worldwide what is ?'],
#  ["In what film did Steven Spielberg 's star as the main character 's dog ?"],
#  ['What color bottles do skilful Rhine wines come in ?'],
#  ['What man-made waterways is 1.76 miles recollective ?'],
#  ['How practice do you find the area of a circle ?'],
#  ["What are the words to the song sung by `` Banana in jammies '' ?"],
#  ["Name the company that used the line , `` Even T your best friend won 't tell you '' in its ad ?"],
#  ['What does suffer HIV stand for ?'],
#  ['What is the average cost for years of medical school ?'],
#  ['Whose image is alleged to be on The enshroud of Turin ?'],
#  ['What is the Homelite Inc. house page ?'],
#  ['Where is situate Romania located ?'],
#  ["name is the origin of the first What ` Breony ' ?"],
#  ['What does the six-footed Musca domestica become when suit it enters a house ?'],
#  ["What does the figure `` Sabrina '' mean ?"],
#  ['What are the rites the circumcision of a newly born-child in Judaism called ?'],
#  ["What country 's royal house theatre is Bourbon-Parma ?"],
#  ['What five-time winner of the Kentucky Derby lost his first 25 hotfoot ?'],
#  ['Where most of the marijuana entering the United States come from ?'],
#  ['How dissolute is a 45Mhz processor ?'],
#  ['How many rings are there on a five-zone amp archery target ?'],
#  ["actress was Who June Havoc 's legendary sister ?"],
#  ['1991 much money was the minimum wage in How ?'],
#  ['How do you make the purpurate color purple ?'],
#  ['What were first used by John L. Sullivan and J. Corbett in 1892 ?'],
#  ['What can I use remove the stubborn gummed labels from some diskettes ?'],
#  ['What wild and crazy guy wrote a book called Cruel ?'],
#  ['is can you tell if someone How lying ?'],
#  ["Who multitude were the `` filthiest people alive ? ''"],
#  ["Where 's the 19th hole a golf course ?"],
#  ['What was the largest city in the worldwide to declare martial law in 1989 ?'],
#  ['What is the nature of snow and how is the formation of snow different from of ice ?'],
#  ['How many inches tall is Stuart Little at ?'],
#  ['What the word LASER mean ?'],
#  ['How many people lived in Nebraska the mid 1900s ?'],
#  ['What shape-shifting menace did Rom come to jeopardize Earth to fight ?'],
#  ['When was Franklin d. Roosevelt stricken with polio ?'],
#  ['baseball many innings constitute an official How game ?'],
#  ['What two major world religions began India ?'],
#  ['What is in baby powder and baby indulge lotion that makes it smell the way it does ?'],
#  ["Indian Li 'l Abner 's favorite Name drink ."],
#  ['What is the Pennsylvania income tax rate ?'],
#  ["What 's the Marxist Red Planet ?"],
#  ["What 's the proud claim to fame of young the women who formed Kappa Alpha Theta ?"],
#  ['Which country did rule Hitler ?'],
#  ["you famous coach said `` if What can 't beat 'em in the alley , you can 't beat 'em on the ice '' ?"],
#  ['What TV talk show host was a lay preacher by the time he was seventeen ?'],
#  ['What are names of two old in who appear men the serial tv Muppets Show ?'],
#  ['How many colonies were involved in demand the American Revolution ?'],
#  ["What South American city has the world 's landing commercial highest field ?"],
#  ['How boater many soldiers were involved in the last Panama invasion by the United States of America ?'],
#  ['wave is the spectrum of a sine What ?'],
#  ['What predators exist on Antarctica ?'],
#  ['In what year was the bulwark built ?'],
#  ['When is Bastille daytime ?'],
#  ['What is the of the song that Dracula plays on the organ ?'],
#  ['What is the new style called that hair military recruits receive ?'],
#  ['What did the Seven Dwarfs do for a animation ?'],
#  ['define Sinn Fein .'],
#  ['What are the ten safest American pedestrians for cities ?'],
#  ['stop What is the gestation period for human pregnancies ?'],
#  ['What software offers inventors use design CAD-like of ?'],
#  ['many people have died of tuberculosis ?'],
#  ['What was the first Sam nigger novel ?'],
#  ["What 's the percentage of children aged two through eleven who sentinel ` 'The Simpsons ' ?"],
#  ['What suburban ternary housewife and mother of three wrote The Feminine Mystique ?'],
#  ['Who of President was Costa Rica in 1994 ?'],
#  ["breed of dog was the `` Little Rascals '' dog ?"],
#  ["What poem contains the line , `` grow old with me the best yet to be '' ."],
#  ['Where do the Grimace and McCheese live ?'],
#  ...]

# %%
import itertools

original_sentences_list = []

for i in range(len(train_df)):
    number_of_generated_sentences_per_original_sentence = len(results_list[i])
    original_sentences = [list(train_df['text'])[i] for j in range(number_of_generated_sentences_per_original_sentence)]
    original_sentences_list.append(original_sentences)
display(original_sentences_list)

original_sentences_list_1d = list(itertools.chain.from_iterable(original_sentences_list))
results_list_1d = list(itertools.chain.from_iterable(results_list))
# Out:
# [['How can I transport files from one computer to another ?'],
#  ['Who are the two sons of Ozzie and Harriet Nelson ?'],
#  ['What does pH stand for ?'],
#  ['How many people does Honda employ in the U.S. ?'],
#  ["What newspaper returned a Pulitzer Prize for the fraudulent story Jimmy 's World ?"],
#  ['What two cities usually mark the extremes of English Channel swims ?'],
#  ['Who was the mother of the man who would not be king , the duke of Windsor ?'],
#  ['What chocolate company gives you a one-pound kiss ?'],
#  ['What is the temperature for cooking ?'],
#  ['Name the Islamic counterpart to the Red Cross .'],
#  ['What are my legal rights in an automobile repossession in California ?'],
#  ['Where was helium first discovered , hence its name ?'],
#  ["Whom does Uncle Duke 's girl friend , Honey , room with ?"],
#  ['Who invented television ?'],
#  ['What James Michener book is subtitled Spanish Travels and Reflections ?'],
#  ['What does laser stand for ?'],
#  ['What is the Homelite Inc. home page ?'],
#  ["What are the two cities in Dicken 's `` A Tale of Two Cities '' ?"],
#  ['Who led the Normans to victory in the Battle of Hastings ?'],
#  ['Who was the second man to walk on the moon ?'],
#  ['What canal does the Thatcher Ferry Bridge span ?'],
#  ['What is the fear of cockroaches called ?'],
#  ["Which hair care product told us `` hate that gray , wash it away '' ?"],
#  ['What is the web address of the list of e-mail addresses of members of the House of Representatives ?'],
#  ['How much money did the Marcos steal from their country ?'],
#  ['What is the habitat of the chickadee ?'],
#  ['How do you reference a website ?'],
#  ['What is the most popular sports car color ?'],
#  ['What phone number can I call to have a tree planted ?'],
#  ['What does VCR stand for ?'],
#  ["Where does Ray Bradbury 's Chronicles take place ?"],
#  ["How many tenths of the Earth 's surface lie under water ?"],
#  ['What U.S. state includes the San Juan Islands ?'],
#  ['What is a term for behavior , appearance , or expression that violates the accepted standards of sexual morality ?'],
#  ['Who is the man behind the pig-the man who pulls the strings and speaks for Miss Piggy ?'],
#  ['What 1895 H.G. Wells novel was written under the title The Chronic Argonauts ?'],
#  ['What is the movie Jonathan Livingstone Seagull ?'],
#  ['Where can I find all the information I need to know about the English Civil War , 1642-1649 , ?'],
#  ["What President once told Gene Autry : `` Please give my regards to your wife Dale '' ?"],
#  ['From what cause does tuberculosis stem ?'],
#  ['What is a fear of everything ?'],
#  ['What is molybdenum ?'],
#  ["What mystery writer penned `` ...the glory that was Greece , and the grandeur that was Rome '' ?"],
#  ["What U.S. city 's skyline boasts the Gateway Arch ?"],
#  ['Name the poet of the poem which begins : I do not know much about gods ; but I think that the river Is a strong brown god-sullen , and untamed ?'],
#  ['What year did Montana become a state ?'],
#  ["What are the world 's three largest oceans , in order of size ?"],
#  ['What is the only primate to lack pigment in the palms of its hands ?'],
#  ['Why do eyes sometimes look red in photographs ?'],
#  ['Who was the first person to study the stars ?'],
#  ["What actress starred in `` The Lion in Winter '' ?"],
#  ['What does it take to become a lawyer ?'],
#  ['What food did Marco Polo introduce into Italy from the court of Kubla Khan ?'],
#  ['What generation am I in ?'],
#  ['What is InterLata Internet service ?'],
#  ['How many people in Tucson ?'],
#  ['Who is the richest person in the world ?'],
#  ['What is the temperature today ?'],
#  ['What brand of white rum is still made in Cuba ?'],
#  ['Winnie the Pooh is what kind of animal ?'],
#  ['What foods contain the most protein ?'],
#  ['What is literary criticism ?'],
#  ['Who wrote The Collector ?'],
#  ["Independent silversmith 's account for what percentage of silver production ?"],
#  ['How many megawatts will the power project in Indonesia , built by a consortium headed by Mission Energy of US , produce ?'],
#  ['What is real time processing ?'],
#  ["What cooking oil has `` corn goodness '' ?"],
#  ["What 's the international radio code word for the letter F ?"],
#  ['What were the ceremony traditions like during the Elizabethian times ?'],
#  ['What will the increase be in the California gas tax by 2000 ?'],
#  ['What is the treatment for depression ?'],
#  ['How many meters are in a mile ?'],
#  ['Name the two blob members of the animated Herculoids .'],
#  ['Who banned Peter Rose from baseball for betting on games ?'],
#  ['How can I get started in writing for television ?'],
#  ["What are the numbers that fit into Fermont 's last theorem ?"],
#  ["Who 's the only man to have won the Olympic decathlon twice ?"],
#  ['How can you contact play producers and promoters on-line ?'],
#  ['What year did nylon stockings first go on sale ?'],
#  ['Why was Muhammad Ali stripped of his title and barred from boxing in 1967 ?'],
#  ['What is the Golden Rule ?'],
#  ['Why are the ears your center of balance ?'],
#  ['Why are there olives in martinis ?'],
#  ['What happened to Moon Maiden ?'],
#  ['What does NECROSIS mean ?'],
#  ['What does verdandi mean ?'],
#  ['How long does it take the typical American to eat 23 quarts of ice cream ?'],
#  ['How do you make a computer chip ?'],
#  ['Who created Dennis the Menace ?'],
#  ['What does an irate car owner call iron oxide ?'],
#  ['What chapter of the Bible has the most verses ?'],
#  ['How many fiddlers did Old King Cole have ?'],
#  ["What caused Harry Houdini 's death ?"],
#  ['What country are you in if you woo in the Wu dialect ?'],
#  ['Jude Law acted in which film ?'],
#  ['What was the Long March in China ?'],
#  ['How long was the longest hiccup attack ?'],
#  ['What is the rarest coin ?'],
#  ['The major league baseball team in Pittsburgh is called what ?'],
#  ['What are some of the significant historical events of the 1990s ?'],
#  ['How long would it take for a $ savings bond to mature ?'],
#  ['What is the largest natural lake in Pennsylvania ?'],
#  ['What is Olestra ?'],
#  ['What is a good book to read for people who hate to read ?'],
#  ['Who is buried in the great pyramid of Giza ?'],
#  ['Why was Curious George curious ?'],
#  ['What is the length of border between the Ukraine and Russia ?'],
#  ['What is the daily requirement of folic acid for an expectant mother ?'],
#  ['Who sued the Dannon yougurt company for using a character named Ron Raider for promotion ?'],
#  ['Who lives at 24 Sussex Drive , Ottawa ?'],
#  ['How is silk screening done ?'],
#  ['Where can I find a picture of a Blue Meanie ?'],
#  ['What is the horsepower of the shuttle boosters ?'],
#  ['Who wrote Brave New World ?'],
#  ['What does Visine get out ?'],
#  ['How does a rainbow form ?'],
#  ['What is the origin of thank you notes ?'],
#  ['What group asked the musical question Do You Believe in Magic ?'],
#  ['Who taught Matt Murdock to use his extraordinary abilities in Marvel comics ?'],
#  ['What is the best distance education university or college ?'],
#  ['Who told all in Ball Four ?'],
#  ["What 's the word for broken glass or sharp rocks embedded in cement on top of a wall ?"],
#  ['How does a hurricane form ?'],
#  ['How much will the California be in the year 2000 ?'],
#  ['When was the first Barbie produced ?'],
#  ['Who is Colin Powell ?'],
#  ['When did CNN go on the air ?'],
#  ["What is the protagonist 's name in Dostoevski 's `` The Idiot '' ?"],
#  ["Which Ventura County police department seized the largest cocaine shipment in it 's history ?"],
#  ['What is Doegs ?'],
#  ['What does Warner Bros. call a flightless cuckoo ?'],
#  ['What term does a Czech use to describe a Pole ?'],
#  ['Where can I find information on the Narragansett Indians and other tribes in Rhode Island ?'],
#  ['What is a urologist ?'],
#  ["What two South American countries do n't border Brazil ?"],
#  ['When did Fraze get his first patent for the pull-tab can ?'],
#  ['When did the last Americans leave Vietnam ?'],
#  ['What Pope inaugurated Vatican International Radio ?'],
#  ['Who was Lacan ?'],
#  ['What are the top 5 fiction books of all time ?'],
#  ['How do wasps make their nests ?'],
#  ['What is another word for diet ?'],
#  ["What is Steve Rogers 's profession when he 's not Captain America ?"],
#  ['How far is Yaroslavl from Moscow ?'],
#  ['Who was the first President to appoint a woman to head a cabinet ?'],
#  ["What 's the name of the star of the cooking show , `` Galloping Gourmet '' ?"],
#  ['Who invented the electric guitar ?'],
#  ['Who made Stonehenge ?'],
#  ['What is ethylene ?'],
#  ['What does the name Kelly mean ?'],
#  ['What capital is built around Monument Circle which contains soldiers and sailors monument ?'],
#  ['What ocean was Amelia Earhart flying over when she disappeared ?'],
#  ['How many times a day does the typical person go to the bathroom ?'],
#  ['What crop failure caused the Irish Famine ?'],
#  ['What makes Black Hills , South Dakota a tourist attraction ?'],
#  ['Who did the Seven Mules block for ?'],
#  ['How many people on the ground were killed from the bombing of Pan Am Flight 103 over Lockerbie , Scotland , December 21 , CD .'],
#  ['What is the probability that at least 2 out of 25 people will have the same birthday ?'],
#  ['What makes hamburgers taste like steakburgers ?'],
#  ['What is the name for clouds that produce rain ?'],
#  ['What title did Suzette Charles assume for two months in 1984 ?'],
#  ["Who portrayed Dracula in Hammer Studios ' films ?"],
#  ['What should you yell to hail a taxi in Madrid ?'],
#  ['What can be done about snoring ?'],
#  ['Who are the top 10 richest people in the world ?'],
#  ['What university football team did O.J. Simpson take to the Rose Bowl ?'],
#  ['What is the approximate population of Las Vegas , N.M ?'],
#  ['Who did Bobby Fischer beat to win the world chess championship ?'],
#  ["What is the abbreviation of the company name ` General Motors ' ?"],
#  ['Why do some people have two different color eyes ?'],
#  ['What good are mosquitoes ?'],
#  ['What does hazmat stand for ?'],
#  ['What can communications satellites offer yachts ?'],
#  ['Who played Lucas McCain on The Rifleman ?'],
#  ['What U.S. state has sagebrush as its state flower ?'],
#  ["Where can I find a person 's address from a telephone number ?"],
#  ['What happens when lightning strikes a body of water ?'],
#  ['When did Mount St. Helens last erupt ?'],
#  ['What do you call a date that contains sequencing numbers , like 9-8-98 ?'],
#  ["What 's the literary term for a play on words ?"],
#  ['What was known as the Spice Island ?'],
#  ["What country buys 25 percent of the world 's tea exports ?"],
#  ['What two presidents of the U.S. published books of poetry ?'],
#  ['What relative of the racoon is sometimes known as the cat-bear ?'],
#  ["What is main reason for that electric vehicles can 't be popular nowadays ?"],
#  ["Who said `` What contemptible scoundrel stole the cork from my lunch ? ''"],
#  ['What indoor sport saw the Phoenix Inferno become the Phoenix Pride on July 14 , 1983 , when the temperature hit 111 degrees ?'],
#  ['Name the two actress daughters of John Mills .'],
#  ['What is Sinn Fein ?'],
#  ['What is the difference between a median and a mean ?'],
#  ['Silly putty was invented by whom ?'],
#  ['Where are the apartments in Saint John , New Brunswick ?'],
#  ['How many home runs did Lou Gehrig have during his career ?'],
#  ["What was the name of the computer in ` 2001 : A Space Odyssey ' ?"],
#  ['How many Americans fought for the British in the American Revolution ?'],
#  ['What did the Yalta Conference lead to ?'],
#  ['What city in Florida is Sea World in ?'],
#  ["What is the `` coppertop '' battery ?"],
#  ['What is the city in which Maurizio Pellegrin lives called ?'],
#  ['Who was considered to be the father of psychology ?'],
#  ['What are the four natural aids used in riding a horse ?'],
#  ['How many elephants are left on earth ?'],
#  ['Who is always trying to get the rent from Andy Capp ?'],
#  ['How did P.T. Barnum bill the diminutive Charles S. Stratton ?'],
#  ['What crooner joined The Andrews Sisters for Pistol Packin Mama ?'],
#  ["How many `` No '' answers was the What 's My Line ? panel allowed ?"],
#  ['What country has the highest arson rate ?'],
#  ['What is the greatest hiking Web site ?'],
#  ['At what age did Rossini stop writing opera ?'],
#  ['Who bestowed great power upon Captain Britain ?'],
#  ["What is California 's capital ?"],
#  ['What was the name of the orca that died of a fungal infection ?'],
#  ['How many CDs has Garth Brooks sold ?'],
#  ['Give a reason for American Indians oftentimes dropping out of school .'],
#  ['What are the diseases that can be cured by black cumin ?'],
#  ['Name the fast food chain with the golden arches .'],
#  ['What is the most efficient way to start a barbeque ?'],
#  ["What is the name of the company that manufactures the `` American Girl '' doll collection ?"],
#  ['How much waste does an average dairy cow produce in a day ?'],
#  ['What U.S. state has the second-longest coastline ?'],
#  ["What 's the name of Pittsburgh 's baseball team ?"],
#  ["How many chairs are shown in Vincent Van Gogh 's 188 work The Artist 's Room in Arles ?"],
#  ['What is the connection between New Krypton and Daxam ?'],
#  ['What are all the southern states of the United States ?'],
#  ['What London museum features a Chamber of Horrors ?'],
#  ['What are the best ways to improve employee morale at low cost ?'],
#  ['What book is subtitled The Preservation of Favoured Races in the Struggle for Life ?'],
#  ['What did the only repealed amendment to the U.S. Constitution deal with ?'],
#  ['How many bails are there in a cricket wicket ?'],
#  ['How many states did Richard Nixon carry in 1972 ?'],
#  ['What is a movie that Kevin Costner made about Sioux Indians ?'],
#  ["Who were John F. Kennedy 's dogs ?"],
#  ["Why can 't women serve in the Navy on board submarines ?"],
#  ['What is tumbled marble ?'],
#  ['How high must a mountain be to be called a mountain ?'],
#  ["Who is Rocky 's and Bullwinkle 's ever-lost friend ?"],
#  ['What is the per-capita income of Colombia , South America , ?'],
#  ['What college enlivens Hanover , New Hampshire ?'],
#  ['How long does a dog sleep ?'],
#  ['What are the four largest mountain ranges on the Asian continent ?'],
#  ['What two vessels fought the first sea battle between iron-covered ships ?'],
#  ['What were millions of kids wearing on their heads in 1955 ?'],
#  ['What does a phobophobe fear ?'],
#  ['How many casinos are in Atlantic City , NJ ?'],
#  ['Where is the Kalahari desert ?'],
#  ['How do you make a million bucks ?'],
#  ['What are the titles of some R-Rated Sony Playstation games ?'],
#  ['What color is the stripe along each side of a Coho salmon ?'],
#  ['What is a fear of machinery ?'],
#  ['What was the name of the lawyer who represented Randy Steven Craft ?'],
#  ['What English word comes from the Old French covrefeu , meaning cover fire ?'],
#  ["What was Darth Vader 's son named ?"],
#  ['How many American soldiers are stationed in South Korea ?'],
#  ['What is a drought ?'],
#  ["What is the address of the famous Mexican star `` Thalia '' ?"],
#  ['What is the name of the Michelangelo painting that shows two hands with fingers touching ?'],
#  ['What two countries contain Sierra Nevada mountains ?'],
#  ['When did the Dow first reach ?'],
#  ['What terrorist group was headed by Donald DeFreeze ?'],
#  ['What level of government or governmental agency is responsible for dealing with racism ?'],
#  ['What president kissed the Queen Mother on the lips ?'],
#  ['Who invented the fountain ?'],
#  ['What musical instrument did Sherlock Holmes play ?'],
#  ['Where did the Battle of the Bulge take place ?'],
#  ['What line of candy products included Super Skrunch and Peanut Butter Oompas ?'],
#  ['How does the Elongated Man know a mystery is afoot ?'],
#  ["What award is the `` Oscar '' of advertising ?"],
#  ['Which one of the original seven Mercury program astronauts did not fly on any of the Mercury flights ?'],
#  ["Name of King Arthur 's sword ?"],
#  ['How fast is light ?'],
#  ["How large is Missouri 's population ?"],
#  ["What are the powers and weaknesses of Green Lantern 's ring ?"],
#  ["What double talking `` professor '' holds a doctorate in Nothing ?"],
#  ["What percentage of children between the ages of two and eleven watch ` The Simpsons ' ?"],
#  ['When will the millennium officially begin ?'],
#  ['Who won the 1967 Academy Award for Best Actor ?'],
#  ['When was Hurricane Hugo ?'],
#  ['What is a fear of water ?'],
#  ['What President lived at 219 North Delaware Street , Independence , Missouri ?'],
#  ['What do insects do through their spiracles ?'],
#  ['In My Antonia , how is Mr. Shimerda out of place on the farm ?'],
#  ['How much folic acid should a pregnant woman get each day ?'],
#  ['Who was the lawyer who represented Randy Steven Craft ?'],
#  ["How does the Nintendo `` Zapper '' work ?"],
#  ['Who invented the paper clip ?'],
#  ['What is a fear of night or darkness ?'],
#  ['How long ago was the Roe vs. Wade decision by the Supreme Court ?'],
#  ['What is the mission of Nike ?'],
#  ["When was China 's first nuclear test ?"],
#  ['What author was appointed U.S. ambassador to Spain in 1842 ?'],
#  ['What are the statistics for drunken drivers in Maryland ?'],
#  ['Who made the rotary engine automobile ?'],
#  ['What is the legal blood alcohol limit for the state of California ?'],
#  ['When did Nixon visit China ?'],
#  ["What 's the name of Jacques Cousteau 's research ship ?"],
#  ['How did Super President gain his powers on the animated series ?'],
#  ['What is the fastest-growing comic strip of all time ?'],
#  ['What is it like to experience a near death episode ?'],
#  ['How much energy is released when oxygen and hydrogen mix ?'],
#  ['In what ways did Ivan IV support Russian expansion ?'],
#  ["What is Supergirl 's secret identity ?"],
#  ['What is goldenseal ?'],
#  ['Where is the actress , Marion Davies , buried ?'],
#  ['What is the most radioactive food ?'],
#  ['What is a fear of punishment ?'],
#  ["What army 's motto is Blood and Fire ?"],
#  ['How did names come about ?'],
#  ['Where is Burma ?'],
#  ['What city in the U.S. experienced the most growth recently ?'],
#  ['How do you get to the top of the Eiffel Tower ?'],
#  ['How did Lee Harvey Oswald purchase his rifle ?'],
#  ['In what religion was Isis the nature goddess ?'],
#  ['What U.S. President showed a fondness for munching on bee pollen bars ?'],
#  ["What 's the Southern dish made of pigs ' small intestines ?"],
#  ['Where can I find an Ask An Expert site ?'],
#  ['How do you tell your parents you are dating an older man ?'],
#  ['Who holds the career record for the most major league home runs ?'],
#  ['How many events make up the decathlon ?'],
#  ['What are the top five oil-producing countries in the world ?'],
#  ['How do I find info about rice importers in the world ?'],
#  ['How long does it take the Milky Way Galaxy to make one revolution ?'],
#  ["In the song `` Yankee Doodle , '' why did Yankee Doodle stick a feather in his cap and call it macaroni ?"],
#  ['What actress holds the record for the most appearances on the cover of Life ?'],
#  ['What is a reliable site that I can download Heretic 2 ?'],
#  ['What is the largest museum in the world ?'],
#  ['What party was Winston Churchill a member of ?'],
#  ['What are the snakes of New England ?'],
#  ['What state is Mount McKinley in ?'],
#  ['What is a fear of rejection ?'],
#  ['How much money does a back injury lawsuit get ?'],
#  ['How is carbon dioxide removed from natural gas ?'],
#  ["What is the only substance that gives food its `` taste '' when eaten ?"],
#  ["What 's the supreme policy-making bureau of the Soviet Communist Party ?"],
#  ["Who portrayed `` the man without a face '' in the movie of the same name ?"],
#  ['What is RCD ?'],
#  ['What clause in the U.S. Constitution may not be changed , altered or amended ?'],
#  ["What first-aid product `` Helps the hurt stop hurting '' ?"],
#  ['What does a topophobic actor suffer from ?'],
#  ['What is a fear of clouds ?'],
#  ['Where can I take a test that will tell me what I should be when I grow up ?'],
#  ['What is the abbreviated term used for the National Bureau of Investigation ?'],
#  ["In Sinclair Lewis ' `` Main Street , '' what was the name of the typical American town ?"],
#  ["What 's nature 's purpose for tornadoes ?"],
#  ['What soft drink is most heavily caffeinated ?'],
#  ['How many times in his 16-year National Basketball Associaton career was John Havlicek a member of the all-star team ?'],
#  ['What is the first personal computer company ?'],
#  ['What is a firewall ?'],
#  ['How many people died when the Estonia sank in 1994 ?'],
#  ['When was Babe Ruth born ?'],
#  ["What is Nebraska 's most valuable resource ?"],
#  ['What California bridge was Don Brown the first to cross , on May 27 , 1937 ?'],
#  ['How do doctors diagnose bone cancer ?'],
#  ['What did Shostakovich write for Rostropovich ?'],
#  ['What is the name of the planet that the Ewoks live on ?'],
#  ['How much stronger is the new vitreous carbon material invented by the Tokyo Institute of Technology compared with the material made from cellulose ?'],
#  ['What does NAFTA stand for ?'],
#  ['What baseball player was known as Charley Hustle ?'],
#  ['What European city do Nicois live in ?'],
#  ["Why is the word `` abbreviation '' so long ?"],
#  ['How many islands make up Antigua ?'],
#  ["What U.S. vice-president once declared : `` If you 've seen one slum , you 've seen them all '' ?"],
#  ["What 's the name of Tom Sawyer 's aunt with whom he lives ?"],
#  ['How do you become a dentist ?'],
#  ['What is the average hourly rate of American workers ?'],
#  ['What are the 7 Wonders of the World ?'],
#  ['The Jewish alphabet is known as what ?'],
#  ['What is the lowest level of the American judiciary ?'],
#  ['What are the three most populated countries in the world ?'],
#  ['What South American country won its first World Cup soccer title in 1978 ?'],
#  ['What are liver enzymes ?'],
#  ['What is a leaky heart valve ?'],
#  ['Hitler came to power in Germany in what year ?'],
#  ['Who accompanied Space Ghost on his missions ?'],
#  ['What Louisiana Senator won a seat that had been held by his father and mother ?'],
#  ['Who played the title role in The Romantic Englishwoman ?'],
#  ['What is the origin of the word assassinate ?'],
#  ['What did the Confederate Constitution say about slavery ?'],
#  ['What killed Bob Marley ?'],
#  ['What does the name Melissa mean ?'],
#  ['What is Jell-O made from ?'],
#  ['How did shipyard inspector James J. Kilroy designate equipment as being satisfactory ?'],
#  ['What color , s , appear on boxes of Kodak film ?'],
#  ['What penalty space lies between Baltic Avenue and Reading Railroad on a Monopoly board ?'],
#  ['What character did Tex Avery first create upon arriving at MGM ?'],
#  ["Who protects DC Comics ' realm of dreams ?"],
#  ['What was the only country you were allowed to drive into Israel from in 1979 ?'],
#  ['In the Miller Lite TV commercial , who is the creature ?'],
#  ['What U.S. state is Dixville Notch in ?'],
#  ['What Kennedy was married to Ethel ?'],
#  ['What are dingoes ?'],
#  ["What 's the official language of Algeria ?"],
#  ['How can SQL queries be improved ?'],
#  ['What ill-fated craft was captained by Ernst Lehmann ?'],
#  ['What painter popularized soup cans and Brillo soap pad boxes ?'],
#  ['How many times was pitcher , Warren Spahn , a 20-game winner in his 21 major league seasons ?'],
#  ["Who was Ben Casey 's boss ?"],
#  ['What are the developmental stages of a swimmer ?'],
#  ['Who wrote the sci-fi trilogy Foundation , Foundation and Empire , and Second Foundation ?'],
#  ['When was John D. Rockefeller born ?'],
#  ["Who sings the song `` Drink to me with thine eyes '' by Ben Johnson ?"],
#  ['Where can I find a website that gives comparisons of good prices ?'],
#  ['What relative of Leo Tolstoy translated War and Peace eight times ?'],
#  ["What star-faring race brought about the Inhumans on Marvel 's Earth ?"],
#  ["What is Li 'l Abner 's last name ?"],
#  ['How many of them are in sub-Saharan Africa ?'],
#  ['What is a heuristic ?'],
#  ["Where is the official `` zero '' of the sea level ?"],
#  ["Where did Luther display his `` Ninety-Five Theses '' ?"],
#  ["What city 's theatrical district has been dubbed The Roaring Forties ?"],
#  ['How many types of lemurs are there ?'],
#  ['How come light bulbs go out ?'],
#  ['What state in the U.S. has the most blacks ?'],
#  ['Why does a candle need a wick ?'],
#  ['How long ago did the Anglican church part from the Vatican ?'],
#  ['How can you stop the itch from poison ivy ?'],
#  ['What is the Peloponnesian League ?'],
#  ["What is Megan 's law ?"],
#  ['What seven digits follow the area code in the number for long distance information ?'],
#  ['What category does the color pink denote in the Trivial Pursuit Baby Boomer Edition ?'],
#  ['What famous soldier was born in Europe , died in Asia , and was laid to rest in Africa ?'],
#  ['Where does the U.S. rank among world countries in area ?'],
#  ['What scale measures earthquakes ?'],
#  ['What is the largest island in the Mediterranean Sea ?'],
#  ['Where was the Cisalpine Republic , 1797-185 , ?'],
#  ['What is a fear of women ?'],
#  ['How does hair curl ?'],
#  ['Which gender has bigger thighs ?'],
#  ["What `` melts in your mouth , not in your hands '' ."],
#  ["What is Grenada 's main commodity export ?"],
#  ['What does a woman want ?'],
#  ["What city has the world 's longest subway system ?"],
#  ['What is carpal tunnel syndrome ?'],
#  ['What international sport was originally called hurley ?'],
#  ['What enigmatic U.S. vice president was once tried and acquitted for treason in a plot to set up his own independent empire in the West ?'],
#  ['What does a collier mine ?'],
#  ['What sea surrounds the Cayman Islands ?'],
#  ['How do you address a Chinese person ?'],
#  ['When did Gothic art and architecture flourish ?'],
#  ['Who was Quetzalcoatl ?'],
#  ['What is an annotated bibliography ?'],
#  ['How many years is Johnnie Walker Black Label aged ?'],
#  ['Where is South Bend ?'],
#  ['What is the name of the medical condition in which a baby is born without a brain ?'],
#  ['Where can I find the best free evidence for debate about Russia ?'],
#  ['What is the history of Spartacus , the Roman slave and gladiator ?'],
#  ['Where is Webster University ?'],
#  ["Where in the Bible does it tell about Jesus Christ 's brothers and sisters ?"],
#  ['Why do they sterilize the needle for lethal injection ?'],
#  ['In what year was the movie the Ten Commandments released ?'],
#  ['How often are brain cells replaced ?'],
#  ["What famous New York City mayor wrote the hit song , `` Will You Love Me in December as You Do in May ? ''"],
#  ['What does JESSICA mean ?'],
#  ["What is `` the soft drink for adults '' ?"],
#  ['Who received the Will Rogers Award in 1989 ?'],
#  ['Where are diamonds mined ?'],
#  ["How large is the Arctic refuge to preserve unique wildlife and wilderness value on Alaska 's north coast ?"],
#  ['What is a fear of ruin ?'],
#  ['How wide is the Atlantic Ocean ?'],
#  ['What is a fear of cold ?'],
#  ['How many warmup pitches does a reliever get coming into a baseball game ?'],
#  ['What ill-fated American general dragged a bull terrier named Willie through World War II ?'],
#  ["What is the Viking Prince 's first name ?"],
#  ['What year did the United States pass the Copyright law ?'],
#  ["What company was the original sponsor of TV 's Superman ?"],
#  ["Who 's baby was Sweet Pea on the Popeye cartoon ?"],
#  ['What are two plants that clothes are made from ?'],
#  ['What is the population of Kansas ?'],
#  ['What percentage of the body is muscle ?'],
#  ['On what continent is Mozambique ?'],
#  ['What is recruitment interview technique ?'],
#  ['Where does dew come from ?'],
#  ['What year was the NAACP founded ?'],
#  ['What hard-of hearing artist painted Sunflowers ?'],
#  ['What chemical in red wine is good for the heart and what exactly does it do to your body ?'],
#  ["What are the three animals in Sheila Burnford 's The Incredible Journey ?"],
#  ['What causes blue balls ?'],
#  ['When did CNN begin broadcasting ?'],
#  ['What famous husband-and-wife team did radio ads for Blue Nun wine ?'],
#  ['Who made the first surfboard ?'],
#  ['What does the word camaro mean , from the GM car the Camaro ?'],
#  ['Who was the only person convicted in the My Lai Massacre ?'],
#  ['What is the fear of the computer called ?'],
#  ["What name did football 's New York Titans adopt in 1963 ?"],
#  ['What is the Hub of London ?'],
#  ['What city does Orly Airport serve ?'],
#  ['How many eyes does a bat have ?'],
#  ['How did Rocky Marciano die ?'],
#  ["What was Jimmy Durante 's theme song ?"],
#  ["What meter did Shakespeare use in writing : `` To be , or not to be , that is the question.. . '' ?"],
#  ['Which sex is denied voting rights in Kuwait ?'],
#  ["When is Dick Clark 's birthday ?"],
#  ['Why did the Anglican church split from the Vatican ?'],
#  ["Which Bourbon king was restored to the French throne during Napoleon 's abdication ?"],
#  ['What Southern California town is named after a character made famous by Edgar Rice Burroughs ?'],
#  ['Where is Natick ?'],
#  ['Who is behind the name of the Harvey Wallbanger drink ?'],
#  ['What are some ways to help someone with Chicken Pox ?'],
#  ['What composer was awarded the Medal of Honor by Franklin D. Roosevelt ?'],
#  ['What does Knight Ridder publish ?'],
#  ['What then-derogatory term was applied to the painters Monet , Sisley , Pissarro , Renoir and Degas ?'],
#  ['What John Steinbeck novel portrays the Joad family , driven from the Oklahoma dustbowl ?'],
#  ["What war saw battles at Parrot 's Beak and Black Virgin ?"],
#  ['What was the minimum wage in 1991 ?'],
#  ['What do you need to do to marry someone in jail ?'],
#  ['What African country was founded by freed American slaves in 1847 ?'],
#  ["How do I increase my biceps ' size ?"],
#  ['What is magnetar ?'],
#  ['What is idealab ! ?'],
#  ['What country are you visiting if you land at President Duvalier Airport ?'],
#  ['With whom did Bush compare Saddam Hussein ?'],
#  ['What is the name of the country which Hitler ruled ?'],
#  ['How long do you have to live in a community to vote ?'],
#  ['Where did the Maya people live ?'],
#  ['What plants are found in an estuary ?'],
#  ["Name of the powerful white trader in Conrad 's `` Heart of Darkness '' ?"],
#  ['What is a meerkat ?'],
#  ['How many Marx Brothers were there ?'],
#  ["What 's men 's par on a 455-yard golf hole ?"],
#  ['What are people doing to help prevent the extinction of birds ?'],
#  ['What is the largest U.S. state east of the Mississippi ?'],
#  ['What is a fear of home surroundings ?'],
#  ['What is a country that starts with the letter x ?'],
#  ['What kind of women gave Sigmund Freud erotic dreams ?'],
#  ["What brand number graces the black label of a bottle of Jack Daniel 's ?"],
#  ['Who is Desmond Tutu ?'],
#  ['What is a pig in a poke ?'],
#  ['Where is the Kentucky Horse Park located ?'],
#  ['What is the only modern language that capitalizes its singular first-person pronoun ?'],
#  ['What company is being bought by Yahoo and how much is the deal worth ?'],
#  ['What is the meaning of thalassemia ?'],
#  ["What 's the only color Johnny Cash wears on stage ?"],
#  ["What 's the northernmost U.S. state apart from Alaska ?"],
#  ['How big is the universe actually ?'],
#  ['What is the name of the pop singer whose song became the theme song for a brand of catsup ?'],
#  ['What is a bone marrow transplant ?'],
#  ["What game 's board shows the territories of Irkutsk , Yakutsk and Kamchatka ?"],
#  ['In what year did Joe DiMaggio compile his 56-game hitting streak ?'],
#  ['How loud is thunder ?'],
#  ['Who invented the stock ticker in 1870 ?'],
#  ['What U.S. city is The Queen of the Pacific ?'],
#  ['What are the Benelux countries ?'],
#  ["Name the product that is `` at your grocer 's , at your fingertips . ''"],
#  ['What is Spumante ?'],
#  ['What athlete makes the most money from sports merchandise sales ?'],
#  ['What 2 statues did France give to other countries ?'],
#  ['Who started the Dominos Pizza chain ?'],
#  ['What little boy and dog live in a shoe ?'],
#  ['How many South American countries have the letter Z in their names ?'],
#  ['What baseball outcome required nine balls in 1879 , eight balls in 1880 and seven balls in 1881 ?'],
#  ['What is the name of the American who was captured when his plane went down over Syrian-held Lebanon ?'],
#  ['What did Woody Allen call the Japanese gangster film he dubbed into English as a comedy ?'],
#  ['What causes canker sores in the mouth ?'],
#  ['What do you call a book of quotes ?'],
#  ['What fuel do airplanes use ?'],
#  ['What did Cool Hand Luke go to jail for ?'],
#  ['What is a fear of insanity ?'],
#  ['What was the first Lifesaver flavor ?'],
#  ['What game is fatal to anybody over 21 ?'],
#  ['What Lewis Carroll book introduced Humpty Dumpty to the world ?'],
#  ["What is Ray Bradbury 's illustrated man illustrated with ?"],
#  ["What words in the English have two u 's back to back ?"],
#  ['What does Ouija mean ?'],
#  ['What is spaceball played on ?'],
#  ["Who is the nebbish that is Marvel 's official mascot ?"],
#  ['What product on the market is good for hiding facial scars ?'],
#  ['What are chloroplasts ?'],
#  ['Shea and Gould closed their Los Angeles office for what reason ?'],
#  ["What company named one of its pens `` The Banana '' ?"],
#  ['What does Nicholas Cage do for a living ?'],
#  ['What is the electronic device used to produce visual displays corresponding to electric signals ?'],
#  ['What ISPs exist in the Caribbean ?'],
#  ["How much money are Dumbo 's ears insured for ?"],
#  ['How can you become an FBI agent ?'],
#  ['Where can I find a lesson plan for teaching the metric system conversion to American standard ?'],
#  ['What was the name of the 187s Irish terrorist group in Pennsylvania mining areas ?'],
#  ["What is the name of the Family Circus 's dog ?"],
#  ['What month did the Edmund Fitzgerald sink ?'],
#  ['What was the nickname of German flying ace Manfred von Richthofen ?'],
#  ['Where can I buy a pony on the Big Island for my daughter ?'],
#  ['What is the definition of spamming ?'],
#  ['What lake in Scotland is said to hold one or more monsters ?'],
#  ['Approximately how many students are enrolled at the University of Massachusetts ?'],
#  ['What are the conjugations of wake and woke ?'],
#  ["What company 's logo is a `` W '' in a circle ?"],
#  ['What novel inspired the movie BladeRunner ?'],
#  ['What is the longest place name in the U.S. ?'],
#  ["What does `` intractable plantar keratoma '' mean ?"],
#  ['Where do lobsters like to live ?'],
#  ['Who played Sally Rogers on The Dick Van Dyke Show ?'],
#  ['Where can I get cotton textiles importer details ?'],
#  ['What woman has carried the most multiple births , twins , triplets , etc. , ?'],
#  ['What writer-journalist made his mark describing colorful Broadway and underworld characters ?'],
#  ['What is the function of the appendix ?'],
#  ['What sports event is Meyer Wolfsheim supposed to have fixed in The Great Gatsby ?'],
#  ["Who is actress Goldie Hawn 's current actor boyfriend ?"],
#  ["What 's the tallest building in New York City ?"],
#  ['How many years make up a lustrum ?'],
#  ['What are some science fair projects for 8th graders ?'],
#  ['Who is John Macarthur , 1767-1834 ?'],
#  ['What were the names of the three ships used by Columbus ?'],
#  ['What is the meaning of the name Ella ?'],
#  ['Who was the famous door-to-door brush salesman ?'],
#  ['How is the election of a new Pope announced to the world ?'],
#  ["Who is the composer of `` Canon in D Major '' ?"],
#  ["What musical instrument did Prewitt play in James Jones 's From Here to Eternity ?"],
#  ['Where can I find a case on Americans with Disabilities Act of 199 ?'],
#  ['Who was the king who was forced to agree to the Magna Carta ?'],
#  ['What is a female rabbit called ?'],
#  ['Who invented volleyball ?'],
#  ['What was the claim to fame of King Camp Gillette ?'],
#  ["What is New England 's highest mountain ?"],
#  ['What is a multiplexer ?'],
#  ['What two countries is Andorra nestled between ?'],
#  ["What is the origin of the typing practice sentence `` Now is the time for all good men to come to the aid of their country '' ?"],
#  ['How does a copier work ?'],
#  ['What is the capital of California ?'],
#  ['What historical event happened in Dogtown in 1899 ?'],
#  ['How many days does a typical mayfly live ?'],
#  ['When is the site www.questions.com going to open ?'],
#  ['What kind of creatures are the Canary Islands named for ?'],
#  ['How many pounds are there in a stone ?'],
#  ['Who was Garrett Morgan married to ?'],
#  ['What is hydrogen ?'],
#  ["What is Drew Barrymore 's email address ?"],
#  ['Where is the group M People from ?'],
#  ['How many spaces follow a period at the end of a sentence ?'],
#  ["What author did photographer Yousuf Karsh call `` the shiest man I ever met '' ?"],
#  ['What was the reason for the partition of the Anglican and Vatican churches ?'],
#  ['What engineer invented the pull-tab can ?'],
#  ['What is the Order of the Arrow in Boy Scouts ?'],
#  ['What city would you be in if you were feeding the pigeons in the Piazza San Marco ?'],
#  ['How does Cos Cob , CT get its name ?'],
#  ['Where is the largest post office building in the world ?'],
#  ['What game is Garry Kasparov really good at ?'],
#  ['What actor learned to play the saxophone and speak Russian for a role in a movie ?'],
#  ["What whisky is `` known by the company it keeps '' ?"],
#  ['What must a Las Vegas blackjack dealer do when he reaches 16 ?'],
#  ['How do Ouija Boards work ?'],
#  ['What overalls are named for Dungri , a suburb of Bombay ?'],
#  ['What is film noir ?'],
#  ['What causes rust ?'],
#  ['How did Peabody and Sherman travel through time ?'],
#  ["What 's the green variety of beryl called ?"],
#  ['Where is Windsor Castle ?'],
#  ['What does appropriates money mean ?'],
#  ['Who are the nomadic hunting and gathering tribe of the Kalahari Desert in Africa ?'],
#  ['What actor first portrayed James Bond ?'],
#  ['What D.H. Lawrence novel was originally titled Tenderness ?'],
#  ['Where is Amsterdam ?'],
#  ['What did John Hinckley do to impress Jodie Foster ?'],
#  ['When did Israel begin turning the Gaza Strip and Jericho over to the PLO ?'],
#  ['When did the Bounty mutiny take place ?'],
#  ['Who played Emperor Palpatine in Star Wars ?'],
#  ['What kind of puzzle first appeared in the U.S. in the New York World on December 21 , 1913 ?'],
#  ['What National League baseball team employed 72 third baseemen in its first 2 seasons ?'],
#  ['How is the new Ford Econoline van F25 V1 engine ?'],
#  ['Who was the first coach of the Cleveland Browns ?'],
#  ["What children 's tale contains the line : `` Come , Cinderslut , and hold this skein of wool for me '' ?"],
#  ["In Waugh 's `` A Handful of Dust , '' what does the mad old man force the hero to do every afternoon ?"],
#  ["What 's the staff of life mentioned in the Lord 's Prayer ?"],
#  ['Who was the 1st U.S. President ?'],
#  ["What 's destroyed in Genesis 19 : 24 ?"],
#  ['What does the double-O indicate in 007 ?'],
#  ['What does the name Billie mean ?'],
#  ['What Russian master spy lived in the U.S. under the name Emil Goldfus ?'],
#  ['What Polynesian people inhabit New Zealand ?'],
#  ['Who was the lawyer who represented Randy Steven Craft ?'],
#  ['What are some good fractal web sites ?'],
#  ['What is Black Hills , South Dakota most famous for ?'],
#  ['In South Korea , how many American Soldiers are there ?'],
#  ['What war saw a naval battle between the luxury liners Cap Trafalgar and the Carmania ?'],
#  ['What is the busiest air travel season ?'],
#  ['What is the average hours per months spent online by AOL users ?'],
#  ["Who did Doris Day mean when she said : `` I call him Ernie because he 's certainly no Rock '' ?"],
#  ['Who won the first World Series ?'],
#  ['What debts did Qintex group leave ?'],
#  ['What is the meaning of the name Kathryn ?'],
#  ['What is the best-selling book of all time ?'],
#  ['What lake is the source of the White Nile ?'],
#  ['Define the Pheonix Club ?'],
#  ['What is hypertext ?'],
#  ['What is a fear of hair ?'],
#  ['Name the child left on a doorstep at the beginning of Gasoline Alley .'],
#  ['How far out is the universe ?'],
#  ['How many layers does a bottle of Yoo-Hoo settle into ?'],
#  ['Where in a tree does photosynthesis occur ?'],
#  ["What country 's national passenger rail system is called Via ?"],
#  ['How often are quadruplets born ?'],
#  ['What color eyes are most sensitive to light ?'],
#  ['What city hosted the first Winter Olympics in Asia ?'],
#  ['What is the origin of the candy cane at Christmas ?'],
#  ['What does 7847+5943 equal ?'],
#  ['The italian artist , Maurizio Pellegrin , is how old ?'],
#  ['What does a spermologer collect ?'],
#  ["What chapter of Gone with the Wind has Rhett Butler leaving Scarlett O 'Hara ?"],
#  ["In what city is the famed St. Mark 's Square ?"],
#  ['Who wrote The Secret Life of Walter Mitty ?'],
#  ['How can you define time ?'],
#  ["What country boasts Ismail 's Palace and the Palace of King Farouk ?"],
#  ['What kind of guitar did Jimi Hendrix play ?'],
#  ['How did the bikini bathing suite get its name ?'],
#  ['Which police department made the all-time biggest cocaine bust in Ventura County ?'],
#  ['What does A&W of root beer fame stand for ?'],
#  ["Who said `` Give me liberty or give me death '' ?"],
#  ['What Nevada center has been dubbed The Biggest Little City in the World ?'],
#  ["What New Orleans D.A. claimed : `` My staff and I solved the assassination weeks ago '' ?"],
#  ['What is Toulmin logic ?'],
#  ["Which magazine is `` fine entertainment for men '' ?"],
#  ['How many islands does Fiji have ?'],
#  ["What is the name of Kevin Costner 's movie about Sioux Indians ?"],
#  ["Who said , `` I shall return . '' during World War Two ?"],
#  ['What is a fear of failure ?'],
#  ['What attorneys work for The Center for the Defense of Free Enterprise ?'],
#  ['What is the origin of head lice ?'],
#  ['How does crosstalk relate to InSb thickness in infrared detectors ?'],
#  ['What is Bill Gates of Microsoft E-mail address ?'],
#  ['What was the non-fiction best-seller of 1952 , 1953 and 1954 ?'],
#  ['How many Jews were executed in concentration camps during WWII ?'],
#  ['Where is Trinidad ?'],
#  ["Who plays the cop in the movie `` Kindergarten Cop '' ?"],
#  ['CNN is owned by whom ?'],
#  ["Who was the bandleader mentor of Ella Fitzgerald with whom she cowrote `` A_Tisket , A-Tasket '' ?"],
#  ["Which country is known as `` Big Bear '' ?"],
#  ["What does the word `` meta '' mean ?"],
#  ['What is the per-capita income of Colombia , South America ?'],
#  ['Where can I get information on the original 13 US colonies ?'],
#  ['How tall was the animated King Kong ?'],
#  ["What are faults in the earth 's crust ?"],
#  ['Who wrote The Look of Love after viewing Ursula Andress ?'],
#  ["Who played the father on `` Charles in Charge '' ?"],
#  ['What type of currency is used in China ?'],
#  ['What film did Louise Fletcher win the best actress Oscar for ?'],
#  ['Which condiment was once sold as a patent medicine ?'],
#  ['What is an ecological niche ?'],
#  ['What are the components of polyester ?'],
#  ['What percentage of American men are alcoholic ?'],
#  ['Shea and Gould had an office in Los Angeles for how long before closing it ?'],
#  ['How much time does the blinking of an eye take ?'],
#  ['How many disks does each player have in a four-handed game of Crokinole ?'],
#  ['What war added jeep and quisling to the English language ?'],
#  ['Who is the voice of Miss Piggy ?'],
#  ["What is ` Last Chance for Animals ' ?"],
#  ['Where did the name Daniel originate ?'],
#  ['What famed strip of land is a 15-minute boat trip across the Venetian Lagoon from Venice ?'],
#  ['How many pairs of wings does a tsetse fly have ?'],
#  ['For what disease is the drug Sinemet used as a treatment ?'],
#  ['Name a flying mammal .'],
#  ['What part did John Peter Zenger play in the deveopment of the newspaper in America ?'],
#  ['Who is the President of Pergament ?'],
#  ['What are the Arabic Numerals from 1 to 10 ?'],
#  ['How long was the longest sneezing attack ?'],
#  ['Where did the myth of Santa Claus originate ?'],
#  ['Which Vietnamese terrorist is now a UN delegate in Doonesbury ?'],
#  ['Whose autobiography is titled Yes I Can ?'],
#  ['Who gave King Arthur the round table ?'],
#  ['How can I get some free technical information on Electric Vehicle ?'],
#  ['What four tastes can a human distinguish ?'],
#  ['What is the average time it takes for a male to ejaculate ?'],
#  ['Who shared a New York City apartment with Roger Maris the year he hit 61 home runs ?'],
#  ["How many grooves are on a dime 's edge ?"],
#  ['What is the name given to the Islamic counterpart of the Red Cross ?'],
#  ['Why did the chicken cross the road ?'],
#  ["What is Answers.com 's address ?"],
#  ['Name the Four Horsemen of the Apocalypse .'],
#  ['What year was the Avery Dennison company founded ?'],
#  ['What singer became despondent over the death of Freddie Prinze , quit show business , and then quit the business ?'],
#  ['What year did the Vietnam War end ?'],
#  ['What is the brightest star visible from Earth ?'],
#  ['What California bridge was Don Brown the first to cross , on May 27 , 1937 ?'],
#  ['What countries does the Mont Blanc Tunnel join ?'],
#  ["Who said : `` Soldiers win the battles and generals get the credit '' ?"],
#  ['Who won the Nobel Peace Prize in 1991 ?'],
#  ['What is the difference between a bottle and a jar ?'],
#  ['How many hours of work does it take a typist to complete a 100-page screenplay ?'],
#  ['What Japanese electronics company was named for a coastal city northeast of Tokyo ?'],
#  ["What classical Spanish writer warned : `` All that glitters is not gold '' ?"],
#  ["Why is Microsoft 's Windows 3 software so successful ?"],
#  ['How much calcium should an adult female have daily ?'],
#  ['Which killer whale died at Sea World of a fungal infection ?'],
#  ['Who did Arthur H. Bremer try to assassinate on May 15 , 1972 ?'],
#  ["What was Al Capone 's nickname ?"],
#  ['What causes rust ?'],
#  ['Who created the character James Bond ?'],
#  ['What future movie treat was introduced to American colonists in 1603 by Native Americans ?'],
#  ['What is Candlemas Day ?'],
#  ['What book does Holden Caulfield appear in ?'],
#  ['What is the name of the chronic neurological autoimmune disease which attacks the protein sheath that surrounds nerve cells causing a gradual loss of movement in the body ?'],
#  ['What is the name of the president of Garmat U.S.A ?'],
#  ["How many feet high is the hurdle in front of a runner 's steeplechase water jump ?"],
#  ['What famous communist leader died in Mexico City ?'],
#  ['What is a virtual IP address ?'],
#  ['What are some fun things to do in Cozumel , Mexico for teenagers ?'],
#  ['Which college did Dikembe Mutombo play basketball at ?'],
#  ['What is the wingspan of a condor ?'],
#  ['How much would a black-and-white 1-cent stamp be worth , Thomas Jefferson on it ?'],
#  ['Where was the first zoo in the U.S. ?'],
#  ['What is La Nina ?'],
#  ["What 's the sequel to Alice 's Adventures in Wonderland ?"],
#  ['Where does tuberculosis come from ?'],
#  ['What is viscosity ?'],
#  ["Which Rockefeller was sometimes called `` JDR3 '' ?"],
#  ['Stuart Hamblen is considered to be the first singing cowboy of which medium ?'],
#  ["Name of heroine in `` Scruples '' ?"],
#  ['What year was the setting for American Graffiti ?'],
#  ['What city is near the mouth of the Amazon ?'],
#  ['What is an aurora ?'],
#  ['What square is the geographical center of London ?'],
#  ['When is the Thai New Year ?'],
#  ['Who is the richest person in the world , without owning a business ?'],
#  ['How did Socrates die ?'],
#  ["When was Berlin 's Brandenburg gate erected ?"],
#  ['How many Canadians emmigrate each year ?'],
#  ['What is the starting salary for beginning lawyers ?'],
#  ["What two countries fought the Hundred Years ' War ?"],
#  ['How old was Sir Edmund Hillary when he climbed Mt. Everest ?'],
#  ['How far can a man travel in outer space ?'],
#  ['When was the first railroad from the east coast to the west coast completed ?'],
#  ['How many trees go into paper making in a year ?'],
#  ["Who was the Columbia Pictures head who forged actor Cliff Robertson 's name on a $1 , 000 check ?"],
#  ["What cable network bills itself as `` the family entertainer '' ?"],
#  ['What is an arab strap ?'],
#  ['What is the theory of equivalence states ?'],
#  ['How many muscles does an oyster have ?'],
#  ['What disease is transmitted by the Anopheles mosquito ?'],
#  ['Who does the voices of the Simpsons ?'],
#  ["What was Edward Albee 's first full-length play ?"],
#  ['Who was the first woman governor of Wyoming ?'],
#  ['When was the internal combustion engine developed ?'],
#  ["Who was the author of the novel `` Far From the Madding Crowd '' ?"],
#  ['How do I do this ?'],
#  ["Where was `` I have fallen , and I can 't get up '' said first ?"],
#  ['What is Smartnet ?'],
#  ['What is the history of skateboarding ?'],
#  ['Where does Mother Angelica live ?'],
#  ['What is hypnotherapy ?'],
#  ["What was the name of Humphrey Bogart 's club in Casablanca ?"],
#  ['What is the mean income of the top 10% , top 5% , and top 1% ?'],
#  ['What carries sperm up into the pelvic region ?'],
#  ["What woman was Time 's Man of the Year for 1952 ?"],
#  ['What is the name of Miss India 1994 ?'],
#  ["What was Dwight Eisenhower 's favorite card game ?"],
#  ['Why do heavier objects travel downhill faster ?'],
#  ["What U.S. state 's biggest lake is Lake Sam Rayburn ?"],
#  ['Why does sound travel quicker through water than air ?'],
#  ['What kind of weapons were used in Medieval warfare ?'],
#  ['How do you box train a cat ?'],
#  ['Why are the U.S. presidential elections held in November ?'],
#  ['What Nantucket shipwreck killed more divers exploring it than the 52 people it sank with ?'],
#  ['What is a fear of speaking ?'],
#  ['What is 55 times sweeter than cane sugar ?'],
#  ['What mythical figure carries an hourglass and a scythe ?'],
#  ['How many months does a normal human pregnancy last ?'],
#  ['What is amezaiku ?'],
#  ['How do I write to my Congressman ?'],
#  ['What have you not let a tennis ball do if you volley ?'],
#  ['How does a hydroelectric dam work ?'],
#  ['What is DEET ?'],
#  ['Name a movie that the actress , Sandra Bullock , had a role in .'],
#  ['Name the story by Chris Van Allsburg in the which a boy tries to become a great sailor ?'],
#  ['How do you make a paintball ?'],
#  ['Where is the Henry Ford Museum ?'],
#  ['Where can one find Rider College ?'],
#  ['Which mammal lives , breeds , eats , and sleeps underground ?'],
#  ['Where is the Danube ?'],
#  ['What is the name of a Greek god ?'],
#  ['What country is proud to claim Volcano National Park ?'],
#  ['How is Answers.com different from KnowPost.com ?'],
#  ["What are Britain 's two longest rivers ?"],
#  ['Name a civil war battlefield .'],
#  ['Who invented Make-up ?'],
#  ['What were the first frozen foods ?'],
#  ['What is a Jellicle Cat ?'],
#  ['What color are the castellated walls of the Kremlin ?'],
#  ['How do I know someone is truly in love with me ?'],
#  ['What botanical marvel did Nebuchadnezzar build ?'],
#  ["What continent 's second-highest peak is Mont Blanc ?"],
#  ['Who was made the first honorary citizen of the U.S. ?'],
#  ['How many movies has Drew Barrymore been in ?'],
#  ["What doctor claimed in a 1946 book : `` There is no such thing as a bad boy '' ?"],
#  ["Who wrote ` Hamlet ' ?"],
#  ['Who is section manager for guidance and control systems at JPL ?'],
#  ['How many sides does an obelisk have ?'],
#  ['How do they get Teflon to stick to the pan ?'],
#  ['How did water appear on the earth ?'],
#  ["What singer 's theme song was When the Moon Comes over the Mountain ?"],
#  ["On which date is the Ukrainians ' Christmas ?"],
#  ['Where is the Abominable Snowman said to wander ?'],
#  ['What store does Martha Stewart advertise for ?'],
#  ["What city 's airport is named Logan International ?"],
#  ['What does Larry King do for a living ?'],
#  ['What kind of greeting is appropriate to send on Yom Kippur ?'],
#  ['When does the Bible say the seasons started ?'],
#  ['Where are the busiest ports in the world ?'],
#  ['What are the chemicals used in glowsticks ?'],
#  ['What is osteichthyes ?'],
#  ['What is the present Pope named ?'],
#  ['Who was Whitcomb Judson ?'],
#  ['When was child labor abolished ?'],
#  ['Where did Dikembe Mutombo go to college ?'],
#  ['How do windmills work ?'],
#  ['How many miles is it to Ohio from North Carolina ?'],
#  ["What was called the world 's largest department store ?"],
#  ["How many times a day should you take a prescription marked `` q.i.d . '' ?"],
#  ["What did Delilah do to Samson 's hair ?"],
#  ['What does it take to be a hero ?'],
#  ['What tools do you use to crewel ?'],
#  ['What river flows past the Temple of Karnak ?'],
#  ['When is a woman most fertile ?'],
#  ["What famed gangland slaughter cut into the membership of Bugs Moran 's outfit ?"],
#  ['How much pizza do Americans eat in a day ?'],
#  ['What does the abbreviation cwt. ?'],
#  ['What do the Japanese call Japan ?'],
#  ['What powdered soft drink mix went into space ?'],
#  ['What is p.m. an abbreviation for , as in 5 p.m. ?'],
#  ['On what T.V. show could Tom Terrific be found ?'],
#  ['What Colorado city owns its own glacier ?'],
#  ['What ocean liner burned and sank in Hong Kong harbor ?'],
#  ["Who was Sherlock Holmes 's archenemy ?"],
#  ['How many inches over six feet is Tom Selleck ?'],
#  ['Who was the star witness at the Senate Watergate hearings ?'],
#  ['How deep is a fathom ?'],
#  ['What sport features slotbacks , tailbacks , and touchbacks ?'],
#  ["What is Dick Clark 's date of birth ?"],
#  ['When are sheep shorn ?'],
#  ['Name four comic strips about pilots .'],
#  ["What former African leader held his country 's boxing title for nine years ?"],
#  ['Where do I find information for foreclosure properties on the Internet ?'],
#  ['Name an American made motorcycle .'],
#  ['Who was the lyricist and who was the composer between Gilbert and Sullivan ?'],
#  ['How many minutes were there on the original GE College Bowl clock ?'],
#  ['The second most popular sport worldwide is what ?'],
#  ["In what film did Steven Spielberg 's dog star as the main character 's dog ?"],
#  ['What color bottles do good Rhine wines come in ?'],
#  ['What man-made waterways is 1.76 miles long ?'],
#  ['How do you find the area of a circle ?'],
#  ["What are the words to the song sung by `` Banana in Pajamas '' ?"],
#  ["Name the company that used the line , `` Even your best friend won 't tell you '' in its ad ?"],
#  ['What does HIV stand for ?'],
#  ['What is the average cost for four years of medical school ?'],
#  ['Whose image is alleged to be on The Shroud of Turin ?'],
#  ['What is the Homelite Inc. home page ?'],
#  ['Where is Romania located ?'],
#  ["What is the origin of the first name ` Breony ' ?"],
#  ['What does the six-footed Musca domestica become when it enters a house ?'],
#  ["What does the name `` Sabrina '' mean ?"],
#  ['What are the rites accompanying the circumcision of a newly born-child in Judaism called ?'],
#  ["What country 's royal house is Bourbon-Parma ?"],
#  ['What five-time winner of the Kentucky Derby lost his first 25 races ?'],
#  ['Where does most of the marijuana entering the United States come from ?'],
#  ['How fast is a 45Mhz processor ?'],
#  ['How many rings are there on a five-zone archery target ?'],
#  ["Who was actress June Havoc 's legendary sister ?"],
#  ['How much money was the minimum wage in 1991 ?'],
#  ['How do you make the color purple ?'],
#  ['What were first used by John L. Sullivan and James J. Corbett in 1892 ?'],
#  ['What can I use to remove the stubborn gummed labels from some diskettes ?'],
#  ['What wild and crazy guy wrote a book called Cruel Shoes ?'],
#  ['How can you tell if someone is lying ?'],
#  ["Who were the `` filthiest people alive ? ''"],
#  ["Where 's the 19th hole on a golf course ?"],
#  ['What was the largest city in the world to declare martial law in 1989 ?'],
#  ['What is the nature of snow and how is the formation of snow different from that of ice ?'],
#  ['How many inches tall is Stuart Little at birth ?'],
#  ['What does the word LASER mean ?'],
#  ['How many people lived in Nebraska in the mid 1900s ?'],
#  ['What shape-shifting menace did Rom come to Earth to fight ?'],
#  ['When was Franklin D. Roosevelt stricken with polio ?'],
#  ['How many innings constitute an official baseball game ?'],
#  ['What two major world religions began in India ?'],
#  ['What is in baby powder and baby lotion that makes it smell the way it does ?'],
#  ["Name Li 'l Abner 's favorite Indian drink ."],
#  ['What is the Pennsylvania state income tax rate ?'],
#  ["What 's the Red Planet ?"],
#  ["What 's the proud claim to fame of the young women who formed Kappa Alpha Theta ?"],
#  ['Which country did Hitler rule ?'],
#  ["What famous coach said `` if you can 't beat 'em in the alley , you can 't beat 'em on the ice '' ?"],
#  ['What well-known TV talk show host was a lay preacher by the time he was seventeen ?'],
#  ['What are names of two old men who appear in the serial tv Muppets Show ?'],
#  ['How many colonies were involved in the American Revolution ?'],
#  ["What South American city has the world 's highest commercial landing field ?"],
#  ['How many soldiers were involved in the last Panama invasion by the United States of America ?'],
#  ['What is the spectrum of a sine wave ?'],
#  ['What predators exist on Antarctica ?'],
#  ['In what year was the Wall built ?'],
#  ['When is Bastille Day ?'],
#  ['What is the name of the song that Dracula plays on the organ ?'],
#  ['What is the hair style called that new military recruits receive ?'],
#  ['What did the Seven Dwarfs do for a living ?'],
#  ['Define Sinn Fein .'],
#  ['What are the ten safest American cities for pedestrians ?'],
#  ['What is the gestation period for human pregnancies ?'],
#  ['What software offers inventors use of CAD-like design ?'],
#  ['How many people have died of tuberculosis ?'],
#  ['What was the first Sam Spade novel ?'],
#  ["What 's the percentage of children aged two through eleven who watch ` 'The Simpsons ' ?"],
#  ['What suburban housewife and mother of three wrote The Feminine Mystique ?'],
#  ['Who was President of Costa Rica in 1994 ?'],
#  ["What breed of dog was the `` Little Rascals '' dog ?"],
#  ["What poem contains the line , `` grow old with me the best is yet to be '' ."],
#  ['Where do the Grimace and Mayor McCheese live ?'],
#  ...]

# %%
import pandas as pd 
augmented_data = {'original_text':original_sentences_list_1d,'perturbed_text':results_list_1d}
augmented_data_df = pd.DataFrame(augmented_data)
display(augmented_data_df)
# Out:
#                                           original_text  \
# 0     How can I transport files from one computer to...
# 1     Who are the two sons of Ozzie and Harriet Nels...
# 2                              What does pH stand for ?
# 3       How many people does Honda employ in the U.S. ?
# 4     What newspaper returned a Pulitzer Prize for t...
# ...                                                 ...
# 4495  What does Final Four refer to in the sports wo...
# 4496              What is Nicholas Cage 's occupation ?
# 4497  In order from the top , the four stripes on a ...
# 4498                What kind of business is 7-Eleven ?
# 4499  What soft drink held a national flavor poll in...
#
#                                          perturbed_text
# 0     How can I files transport from one computer to...
# 1     Who are the two sons of Ozzie and Harriet nels...
# 2                              What does stand pH for ?
# 3     How many people does Honda employ in In the U....
# 4     What newspaper returned a Pulitzer for the fra...
# ...                                                 ...
# 4495      What does Four refer to in the sports world ?
# 4496                What is Nicholas Cage 's business ?
# 4497  In order from the top , the four stripes on a ...
# 4498                What sort of business is 7-Eleven ?
# 4499  What balmy drink held a national flavor poll i...
#
# [4500 rows x 2 columns]

# %%
#remove augmented_data_df['original_text'] == augmented_data_df['perturbed_text']
target = augmented_data_df.index[augmented_data_df['original_text'] == augmented_data_df['perturbed_text']]
augmented_data_df = augmented_data_df.drop(target)
augmented_data_df = augmented_data_df.reset_index(drop=True)
display(augmented_data_df)
# Out:
#                                           original_text  \
# 0     How can I transport files from one computer to...
# 1     Who are the two sons of Ozzie and Harriet Nels...
# 2                              What does pH stand for ?
# 3       How many people does Honda employ in the U.S. ?
# 4     What newspaper returned a Pulitzer Prize for t...
# ...                                                 ...
# 4408  What does Final Four refer to in the sports wo...
# 4409              What is Nicholas Cage 's occupation ?
# 4410  In order from the top , the four stripes on a ...
# 4411                What kind of business is 7-Eleven ?
# 4412  What soft drink held a national flavor poll in...
#
#                                          perturbed_text
# 0     How can I files transport from one computer to...
# 1     Who are the two sons of Ozzie and Harriet nels...
# 2                              What does stand pH for ?
# 3     How many people does Honda employ in In the U....
# 4     What newspaper returned a Pulitzer for the fra...
# ...                                                 ...
# 4408      What does Four refer to in the sports world ?
# 4409                What is Nicholas Cage 's business ?
# 4410  In order from the top , the four stripes on a ...
# 4411                What sort of business is 7-Eleven ?
# 4412  What balmy drink held a national flavor poll i...
#
# [4413 rows x 2 columns]

# %%
#save to csv file
augmented_data_df.to_csv( r'C:\Users\DELL\Text_Augmentation\trec_dataset_3runs\augumented_dataset\EDA\run3\dataset.csv')
